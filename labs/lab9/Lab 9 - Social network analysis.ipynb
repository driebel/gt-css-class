# %% [markdown]
# # Lab 9: Social Network Analysis
#
# In this lab, we will explore a social network of legislators and the organizations that contribute to their campaigns.
#
# The data is from [opensecrets.org](opensecrets.org), which collects public records about campaign finance in the United States.
#
# We'll use `networkx`, a python package for social network analysis.

# %%
import pandas as pd
import networkx as nx
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## The legislators
#
# Information about each of the legislators (in the US Congress and Senate) is stored in `legislators.csv`. We'll use Pandas to read it into a dataframe.

# %%
df = pd.read_csv('legislators.csv',index_col=0)

# %% [markdown]
# ## Exploring the legislators data frame

# %%
df.head(3)
# Out:
#   bioguide_id   birthdate        cid comments  \
# 0     L000578  1960-07-02  N00033987      NaN
# 1     H001068  1964-02-18  N00033030      NaN
# 2     G000559  1945-01-24  N00030856      NaN
#
#                         congress_office  exit_code   facebook_id  \
# 0      322 Cannon House Office Building          0    RepLaMalfa
# 1  1406 Longworth House Office Building          0    RepHuffman
# 2    2438 Rayburn House Office Building          0  repgaramendi
#
#             fax  feccandid  first_elected                ...                  \
# 0  530-534-7800  H2CA02142           2012                ...
# 1  202-225-5163  H2CA06259           2012                ...
# 2  202-225-5914  H0CA10149           2009                ...
#
#   gender   lastname office party         phone    twitter_id votesmart_id  \
# 0      M    LAMALFA   CA01     R  202-225-3076    RepLaMalfa      29713.0
# 1      M    HUFFMAN   CA02     D  202-225-5161    RepHuffman      59849.0
# 2      M  GARAMENDI   CA03     D  202-225-1880  RepGaramendi      29664.0
#
#                                            webform  \
# 0       https://lamalfa.house.gov/contact/email-me
# 1       https://huffman.house.gov/contact/email-me
# 2  https://garamendi.house.gov/contact-me/email-me
#
#                       website                        youtube_url
# 0    http://lamalfa.house.gov     https://youtube.com/RepLaMalfa
# 1    http://huffman.house.gov     https://youtube.com/rephuffman
# 2  http://garamendi.house.gov  https://youtube.com/garamendiCA10
#
# [3 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['bioguide_id', 'birthdate', 'cid', 'comments', 'congress_office',
#        'exit_code', 'facebook_id', 'fax', 'feccandid', 'first_elected',
#        'firstlast', 'gender', 'lastname', 'office', 'party', 'phone',
#        'twitter_id', 'votesmart_id', 'webform', 'website', 'youtube_url'],
#       dtype='object')

# %% [markdown]
# Let's look at Atlanta's congressional representative, John Lewis.

# %%
df.loc[df['firstlast']=='John Lewis']
# Out:
#     bioguide_id   birthdate        cid comments  \
# 203     L000287  1940-02-21  N00002577      NaN
#
#                       congress_office  exit_code   facebook_id           fax  \
# 203  343 Cannon House Office Building          0  RepJohnLewis  202-225-0351
#
#      feccandid  first_elected                ...                gender  \
# 203  H6GA05217           1986                ...                     M
#
#     lastname office party         phone    twitter_id votesmart_id  \
# 203    LEWIS   GA05     D  202-225-3801  RepJohnLewis      26820.0
#
#                                                webform  \
# 203  https://johnlewis.house.gov/contact-me/email-m...
#
#                          website                       youtube_url
# 203  https://johnlewis.house.gov  https://youtube.com/repjohnlewis
#
# [1 rows x 21 columns]

# %% [markdown]
# To facilitate looking up legislators, here are some helper functions. The `cid` is a unique identifier per candidate.

# %%
get_leg_by_name = lambda name : df.loc[df['firstlast']==name]
get_leg_by_cid = lambda cid : df.loc[df['cid']==cid]

# %%
get_leg_by_name('John Lewis')
# Out:
#     bioguide_id   birthdate        cid comments  \
# 203     L000287  1940-02-21  N00002577      NaN
#
#                       congress_office  exit_code   facebook_id           fax  \
# 203  343 Cannon House Office Building          0  RepJohnLewis  202-225-0351
#
#      feccandid  first_elected                ...                gender  \
# 203  H6GA05217           1986                ...                     M
#
#     lastname office party         phone    twitter_id votesmart_id  \
# 203    LEWIS   GA05     D  202-225-3801  RepJohnLewis      26820.0
#
#                                                webform  \
# 203  https://johnlewis.house.gov/contact-me/email-m...
#
#                          website                       youtube_url
# 203  https://johnlewis.house.gov  https://youtube.com/repjohnlewis
#
# [1 rows x 21 columns]

# %%
#Find the record for the youngest legislator in the data:
df.loc[df['birthdate']==min(df['birthdate'])]
# Out:
#     bioguide_id   birthdate        cid comments  \
# 318     C000714  1929-05-16  N00004029      NaN
#
#                         congress_office  exit_code         facebook_id  \
# 318  2426 Rayburn House Office Building          0  CongressmanConyers
#
#               fax  feccandid  first_elected             ...              \
# 318  202-225-0072  H6MI01028           1964             ...
#
#     gender lastname office party         phone      twitter_id votesmart_id  \
# 318      M  CONYERS   MI13     D  202-225-5126  RepJohnConyers      26904.0
#
#                                                webform  \
# 318  https://conyers.house.gov/index.cfm/online-con...
#
#                        website                 youtube_url
# 318  https://conyers.house.gov  https://youtube.com/JCMI14
#
# [1 rows x 21 columns]

# %% [markdown]
# **Your turn** Find the record of the youngest legislator in the data. (Hint: use the field `birthdate`.)

# %%
# write a functiomn to do so
get_small = lambda birthdate : df.loc[df['birthdate']==min(df['birthdate'])]

# %%
get_small('birthdate')
# Out:
#     bioguide_id   birthdate        cid comments  \
# 318     C000714  1929-05-16  N00004029      NaN
#
#                         congress_office  exit_code         facebook_id  \
# 318  2426 Rayburn House Office Building          0  CongressmanConyers
#
#               fax  feccandid  first_elected             ...              \
# 318  202-225-0072  H6MI01028           1964             ...
#
#     gender lastname office party         phone      twitter_id votesmart_id  \
# 318      M  CONYERS   MI13     D  202-225-5126  RepJohnConyers      26904.0
#
#                                                webform  \
# 318  https://conyers.house.gov/index.cfm/online-con...
#
#                        website                 youtube_url
# 318  https://conyers.house.gov  https://youtube.com/JCMI14
#
# [1 rows x 21 columns]

# %%
get_small_any = lambda varname : df.loc[df[varname]==min(df[varname])]

# %%
get_small_any('birthdate')
# Out:
#     bioguide_id   birthdate        cid comments  \
# 318     C000714  1929-05-16  N00004029      NaN
#
#                         congress_office  exit_code         facebook_id  \
# 318  2426 Rayburn House Office Building          0  CongressmanConyers
#
#               fax  feccandid  first_elected             ...              \
# 318  202-225-0072  H6MI01028           1964             ...
#
#     gender lastname office party         phone      twitter_id votesmart_id  \
# 318      M  CONYERS   MI13     D  202-225-5126  RepJohnConyers      26904.0
#
#                                                webform  \
# 318  https://conyers.house.gov/index.cfm/online-con...
#
#                        website                 youtube_url
# 318  https://conyers.house.gov  https://youtube.com/JCMI14
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Exploring the social network
#
# Now let's load in the social network between legislators and contributors. It's stored as an XML file; see the github repository for another notebook that shows how this data was acquired from opensecret's API.

# %%
G = nx.read_gexf('contributions.xml')

# %% [markdown]
# Let's look at some properties of the network. First we will check if it is **bipartite**. This means that the nodes can be divided into two sets, and all edges include exactly one node from each set. This should be true by construction, since each edge indicates one contributor and one legislator.

# %%
nx.is_bipartite(G)
# Out:
# True

# %% [markdown]
# Now let's check if the network is connected (remember what this means from class and the readings?)

# %%
nx.is_connected(G)
# Out:
# False

# %% [markdown]
# The fact that the network is not connected means that there are pairs of nodes between whom there is no path. Let's see if it is nearly connected.

# %%
print('Number of nodes: %d'%len(G.nodes()))
print('Largest component: %d'%len(max(nx.connected_components(G))))
#Question?
# Out:
# Number of nodes: 2413
# Largest component: 2401

# %% [markdown]
# Although the network isn't connected, 954 of the nodes are in the single largest component.
# This indicates that there is a path between nearly every pair of nodes in the network.
#
# Now let's compute the **transitivity**. This is the fraction of triads $(a,b,c)$ which are connected but are not **cliques**: edges $(a,b)$ and $(b,c)$ exist, but $(a,c)$ does not exist.

# %%
nx.transitivity(G)
# Out:
# 0.0

# %% [markdown]
# **Discuss**: Make sure you understand why the transitivity must be zero in a bipartite graph.

# %% [markdown]
# ## Neighbors

# %% [markdown]
# It will be helpful to differentiate all nodes that are legislators and nodes that are contributors.

# %%
#create a list of legislator nodes
leg_nodes = [node for node in G.nodes() if node in list(df['cid'])]

# %%
leg_nodes[1:5]
# Out:
# ['N00026710', 'N00025495', 'N00035403', 'N00001746']

# %%
#there are 537 legislators
len(leg_nodes)
# Out:
# 537

# %%
#now create a list of contributor nodes
test = set(G.nodes())-set(leg_nodes)

# %%
len(test)
# Out:
# 1876

# %%
test
# Out:
# {'Maryland Assn for Concerned Citizens',
#  'Wolverine Gas & Oil',
#  'Gleason, Cherry & Cherry',
#  'National Assn of Realtors',
#  'US Senate',
#  'Telephone & Data Systems Inc',
#  "Love's Travel Stops",
#  'Sun Capital Partners',
#  'Cinemark Holdings',
#  'Yale University',
#  'Allegiancy',
#  'Asuragen',
#  'Keyes Automotive Group',
#  'United Mine Workers of America',
#  'International Paper',
#  'Kmg Tool',
#  'Bonanza Oil',
#  'Hercules Holding',
#  'Bram Corp',
#  'State of New Hampshire',
#  'Charter Brokerage LLC',
#  'Matson Inc',
#  'Radiance Technologies',
#  'Granite Telecommunications',
#  'Burdick Automotive',
#  'Prudential Financial',
#  'Field Fresh Foods',
#  'Great Lakes Sugar Beet Growers Assn',
#  'Platinum Health Care',
#  'Derick Dermatology',
#  'Goldberg, Persky & White',
#  'Almost Family Inc',
#  'Alabama Farmers Federation',
#  'State of Illinois',
#  'Koch Enterprises',
#  'Daybrook Fisheries',
#  'McDermott, Will & Emery',
#  "Big Al's-Barrel Cellars",
#  'Hy-Vee Inc',
#  'LCF Enterprises',
#  'Alliant Techsystems',
#  'Roark Capital Group',
#  'Stanford University',
#  'Boston Finance Group',
#  'Automotive Free International Trade PAC',
#  'North Star Companies',
#  'Leadership for American Opportunity',
#  'Pinnacle Bancorp',
#  'State of Washington',
#  'ActBlue',
#  'Apollo Global Management',
#  'Atlas Air Worldwide',
#  'Boston Scientific Corp',
#  'Munger, Tolles & Olson',
#  'Cantu Construction',
#  'National Assn of Chain Drug Stores',
#  'University of Montana',
#  'Regional Urology',
#  'Abc Supply',
#  'McKee Foods',
#  'Nelson, Mullins et al',
#  'Credit Suisse Group',
#  'Cancer Treatment Centers of America',
#  'American Development Corp',
#  'Monroe College',
#  'Cohen Group',
#  'Triumph Group',
#  'Mimedx Group',
#  'Soros Fund Management',
#  'Blue Dog PAC',
#  'University of Missouri',
#  'Deltic Timber',
#  'Firmgreen Inc',
#  'Marquis Energy',
#  'Element Electronics',
#  'HIG Capital',
#  'Dairy Farmers of America',
#  'Columbia University',
#  'Gdc Properties',
#  'Westport Properties',
#  'Wine Institute',
#  'Federal Aviation Admin Managers Assn',
#  'American Refining Group',
#  'Freedom Fund',
#  'Duane Morris LLP',
#  'JR Simplot Co',
#  'WPX Energy',
#  'Hendrick Motorsports',
#  'Capital Funding Group',
#  'Broadway National Bank',
#  'American Speech-Language-Hearing Assn',
#  'Southeastern Freight Lines',
#  'Emerson Electric',
#  'Surgical Care Affiliates',
#  'American Assn of Nurse Anesthetists',
#  'Bridge Capital',
#  'Harris Farms',
#  'Archer & Greiner',
#  'Montverde Academy',
#  'Duke Energy',
#  'Resurgens Orthopaedics',
#  'Irving Moskowitz Foundation',
#  'Shipman & Goodwin',
#  'South Texas Renal Care Group',
#  'Alexion Pharmaceuticals',
#  'The Villages',
#  'PPL Corp',
#  'Willoughby & Hoefer',
#  'Sheetz Inc',
#  'University of New Mexico',
#  'McVean Trading & Investments',
#  'Breckenridge Grand Vacations',
#  'BRIDGE PAC',
#  'Airbus Group',
#  'National Ready Mixed Concrete Assn',
#  'Mmr Constructors',
#  'Lozier Corp',
#  'Dell Inc',
#  'Stoel, Rives et al',
#  'Varney Agency',
#  'News Corp',
#  'Preston Development',
#  'Bravo Cadillac',
#  'GCI',
#  'Washington University In St Louis',
#  'Envirosep',
#  'Cdi',
#  'SchoolsFirst Federal Credit Union',
#  'Marotta Controls',
#  'Coalition for Student Success',
#  'Akonadi Foundation',
#  'Altria Group',
#  'Omnicom Group',
#  'Matrix Energy',
#  'Snell & Wilmer',
#  'Teramana Enterprises',
#  'Archer Daniels Midland',
#  'Celgene Corp',
#  'Hubbard Broadcasting',
#  'Admin Services Cooperative',
#  'American Institute of Architects',
#  'Rancho Deluxe Film Studio',
#  'American Optometric Assn',
#  'Arvest Bank Group',
#  'National HealthCare Corp',
#  'Fierce Government Relations',
#  'North Shore Hematology Oncology Associates',
#  'Nhc Healthcare',
#  'Avant Inc',
#  'BASF SE',
#  'T Rowe Price',
#  'Anheuser-Busch InBev',
#  'Cubic Corp',
#  'Nuclear Energy Institute',
#  'North Georgia Turf',
#  'Estee Lauder Companies',
#  'Crawford Group',
#  'Steel Equities',
#  'Varischetti & Sons',
#  'Novogradac & Co',
#  'GCG Partners',
#  'Cardio-Imaging of Naples',
#  'TeleCommunication Systems Inc',
#  'American Pharmacists Assn',
#  'AT&T Inc',
#  'Captive-Aire Inc',
#  'Graham Companies',
#  'Monsanto Co',
#  'Ice Miller LLP',
#  'Regions Financial',
#  'Murphy Oil',
#  'Sukup Manufacturing',
#  'Tree Top Ranches',
#  'Robert H Zoellner & Assoc',
#  'Cops Monitoring',
#  'Liberman Broadcasting',
#  'COLE PAC',
#  'Altos Eye Physicians',
#  'National Stone, Sand & Gravel Assn',
#  'National Music Publishers Assn',
#  'Parker Towing',
#  'FivePoint Holdings',
#  'Molina Healthcare',
#  'First Premier Bank',
#  'Chemed Corp',
#  'Franklin L Haney Co',
#  'Ball Homes',
#  'Mentor Network',
#  'Zions Bancorp',
#  'Air Products & Chemicals Inc',
#  'Saker ShopRites',
#  'Ariel Corp',
#  'Rock Creek Group',
#  'Stevens & Lee',
#  'Democratic Congressional Campaign Cmte',
#  'American Peanut Shellers Assn',
#  'Simmons First National',
#  'BAE Systems',
#  'USA Rice Federation',
#  'Island Marine',
#  'National Assn of Broadcasters',
#  'Sandhills Publishing',
#  'Merck & Co',
#  'Fragomen, Del Rey et al',
#  'Superior Foods',
#  'NRP Group',
#  'National Education Assn',
#  'Caterpillar Inc',
#  'Morning Fresh Farms',
#  'Citizens United',
#  'Arizona Tile',
#  'Ucor',
#  'ConocoPhillips',
#  'Leggett & Platt',
#  'Southwest Airlines',
#  'Blue Diamond Growers',
#  'Rockport Healthcare Services',
#  'National Assn of Truck Stop Operators',
#  'Pacers Sports & Entertainment',
#  'Genworth Financial',
#  'Mack Energy',
#  'American Academy of Otolaryngology',
#  'CONSOL Energy',
#  'Lee Properties',
#  'Capehart & Scatchard',
#  'National Auto Dealers Assn',
#  'Motorola Solutions',
#  'National Assn of Home Builders',
#  'Sawdey Solution Services',
#  'Freedom Project',
#  'Power Financial Corp',
#  'Alaska Air Group',
#  'Laborers Union',
#  'Crown Holdings',
#  'Portables Unlimited',
#  'California Rice Industry Assn',
#  'Genesis 10',
#  'Signal Hill Petroleum',
#  'Jay Cashman Inc',
#  'King Capital',
#  'L Star',
#  'East Tennessee Pain Medicine',
#  'Tennessee Industrial Electronics',
#  'Chilton Investments',
#  'Bloomberg Lp',
#  'Haury & Smith Contractors',
#  'Campbell Co',
#  'Alqimi Group',
#  'Blessey Marine Service',
#  'California Resources Corp',
#  'Fischer Properties',
#  'Eugene Lee Inc',
#  'James E Hall',
#  'Artech Industries',
#  'Council of Insurance Agents & Brokers',
#  'Johnson Machinery',
#  'Airtech Advanced Materials Group',
#  'Centene Corp',
#  'Hackman Capital Partners',
#  'Wellmont',
#  'Cypress Real Estate Advisors',
#  'Windquest Group',
#  'Eagle Aluminum Cast Products',
#  'Guardian Industries',
#  'Rudin Management',
#  'Plainscapital Corp',
#  'Oil-Dri Corp of America',
#  'Walter P Moore & Assoc',
#  'McT Industries',
#  'Tate Enterprises',
#  'Suburban Collection',
#  'UPMC Health System',
#  'AegisPAC',
#  'American Assn/Oral & Maxillofacial Surg',
#  'Charles Schwab Corp',
#  'First Principles Fund',
#  'American Congress of Obstetricians & Gynecologists',
#  'Republican Main Street Partnership',
#  'AECOM Global',
#  'University of Minnesota',
#  'FMR Corp',
#  'Harbour Group Industries',
#  'Microsoft Corp',
#  'Jones Walker LLP',
#  'Sinclair Companies',
#  'Mockler Beverage',
#  'Brownstein, Hyatt et al',
#  'AstraZeneca PLC',
#  'Livingston Group',
#  'Greater New York Hospital Assn',
#  'Jelly Belly Candy',
#  'HECK YES! VICTORY FUND',
#  'IBE Trade',
#  'AmeriPAC: The Fund for a Greater America',
#  'AEGON NV',
#  'Liquid Environmental Solutions',
#  'Columbia Vista Corp',
#  'AVT Ventures',
#  'Covington & Burling',
#  'Marlin Management Co',
#  'Healthmark Ventures',
#  'Majestic Realty',
#  "Lowe's Companies",
#  'Zivity LLC',
#  'CME Group',
#  'Foley & Lardner',
#  'Mepco LLC',
#  'Leadership Matters for America',
#  'Abbott Laboratories',
#  'Aloha Partners',
#  'DLA Piper',
#  'Federation of American Hospitals',
#  'Xcel Energy',
#  'Caremi Partners',
#  'Air Line Pilots Assn',
#  'Comerica Inc',
#  'Direct Supply Inc',
#  'Ropes & Gray',
#  'Bolla Management',
#  'Midwest Values PAC',
#  'BP',
#  'Linde AG',
#  'Centaur Gaming',
#  'Live Oak Bank',
#  'Procter & Gamble',
#  'Fortress Investment Group',
#  'Gilead Sciences',
#  'Dunlap & Kyle',
#  'Pohlad Companies',
#  'Northern Arizona University',
#  'McM Corp',
#  'QTC Management',
#  'Deere & Co',
#  'ICE Group',
#  'Cintas Corp',
#  'Sentinel Real Estate',
#  'Research Affiliates LLC',
#  'Massillon Cable TV',
#  'Democrats Time In Nevada',
#  'Forhan Co',
#  'Florida Emergency Physicians',
#  'United Minerals & Properties',
#  'Mansour Co',
#  'American Society of Travel Agents',
#  'Conway Mackenzie',
#  'HealthSouth Corp',
#  'Atco Investment',
#  'Seacoast Commerce Bank',
#  'Kinsey Interests',
#  'Kojaian Companies',
#  'Dex Imaging',
#  'United Parcel Service',
#  'Charmer Sunbelt Group',
#  'Cooper Communities',
#  "Rubie's Costumes",
#  'Pvs Chemicals',
#  'Noble Energy',
#  'Velocity Solutions',
#  'Marriott International',
#  'Club for Growth',
#  'LaSalle Management',
#  'Lee, Hong et al',
#  'American Financial Services Assn',
#  'Felix Chi-Ming Yip Md',
#  'Las Vegas Sands',
#  'Small Business Investor Alliance',
#  'Alexander & Baldwin',
#  'Powell Construction',
#  'Florida Citrus Mutual',
#  'Fun Spot of Florida LLC',
#  'Nan Inc',
#  'L&R Structural',
#  'Gilbert & Jacki Cisneros Foundation',
#  'Allied Pilots Assn',
#  "National Cattlemen's Beef Assn",
#  'Alliance Resource Partners',
#  'American Academy of Neurology',
#  'Gryphon Technologies',
#  'Sinclair Broadcast Group',
#  'Akin, Gump Et Al',
#  'National Healthcare Corp',
#  'Xr Trading',
#  'Murphy Endeavors',
#  'Cherokee Nation',
#  'Tregan Partners',
#  'Millard Group',
#  'Paul, Weiss et al',
#  'Pop Fishing & Marine',
#  'Best Line Equipment',
#  'Nike Inc',
#  'American Chiropractic Assn',
#  'Friedkin Group',
#  'Consumer Technology Assn',
#  'At Last Sportswear',
#  'United Contractors Midwest',
#  'Wellington Orthopaedics',
#  'Principal Financial Group',
#  'Heritage Title Co of Austin',
#  'McCombs Enterprises',
#  'Save Our Heritage',
#  'NV Energy',
#  'Massachusetts Mutual Life Insurance',
#  'Rent-A-Center',
#  'Peachtree Orthopaedic Clinic',
#  'Democratic State Central Cmte of Ca',
#  'American Investment Council',
#  'Tensor Engineering',
#  'Citizens for Prosperity in America Today',
#  'Cardinal Health',
#  'Solar Sources',
#  'MGM Resorts International',
#  'Intelsat Holdings',
#  'Intuitive Surgical',
#  'Circle Packaging Machinery',
#  'Lowenstein Sandler LLP',
#  'Deason Capital Services',
#  'Dr Pepper Snapple Group',
#  'L&F Distributors',
#  'Port City Group',
#  'Congressional Black Caucus PAC',
#  'Garden State Medical Center',
#  'Reed Smith LLP',
#  'Herman Estate Trust',
#  'Senate Conservatives Fund',
#  'Koch Industries',
#  'Ruan Companies',
#  'Fedex Corp',
#  'Eglet Law',
#  'Everglades College',
#  'Knight Transportation',
#  'Peabody Energy',
#  'Brius Healthcare Services',
#  'Maxwell Group',
#  'Bronx-Lebanon Hospital Center',
#  'BB&T Corp',
#  'RJ Corman Railroad Group',
#  'Texas Star Investments',
#  'Bates Amusements',
#  'Mantech International',
#  'Toys R Us',
#  'Citizens Organized PAC',
#  'Invus Group',
#  'NorPAC',
#  'Lamar Advertising',
#  'Burns & McDonnell',
#  'Digital Canal Corp',
#  'Motley Rice LLC',
#  'Gross Builders',
#  'Forest City Enterprises',
#  'Alston & Bird',
#  'Millennium Partners',
#  'Amway/Alticor Inc',
#  'Blackstone Group',
#  'Third Point LLC',
#  'Stronghold Engineering',
#  'Nutramax Laboratories',
#  'Solil Management',
#  'Bass Pro Shops',
#  'King & Spalding',
#  'Facebook Inc',
#  'American Council of Life Insurers',
#  'Husch Blackwell LLP',
#  'London Bridge Trading',
#  'Berkeley Patients Group',
#  'American Pistachio Growers',
#  'David Allen Co',
#  'Truman Arnold Companies',
#  'M&R Management',
#  'Tcmi Inc',
#  'Democratic Party of California',
#  'Ozark Mountain Poultry',
#  'Gibbons PC',
#  'Global Partners LP',
#  'CMI Group',
#  'Berkshire Hathaway',
#  'Asplundh Tree Expert Co',
#  'Quadric Group',
#  'Rubin & Rudman',
#  'Proskauer Rose',
#  'Block Communications',
#  'Rising Realty Partners',
#  'Holtec International',
#  'Act for Entertainment',
#  'Prosperity Action',
#  'Independent Community Bankers of America',
#  'Weitz & Luxenberg',
#  'Penn Hill Group',
#  'Oasis Petroleum',
#  'McMahon Financial',
#  'Diamond Pet Foods',
#  'Stephens Group',
#  'National Assn of Convenience Stores',
#  'QC Holdings',
#  'Brown-Forman Corp',
#  'Crescent Capital Group',
#  'American Chemistry Council',
#  'DaVita HealthCare Partners',
#  "O'Melveny & Myers",
#  'G&J Pepsi-Cola Bottlers',
#  'Power, Rogers & Smith',
#  'Cleveland Clinic',
#  'PNC Financial Services',
#  'Phoenix American Insurance Group',
#  'House Liberty Fund',
#  'Sheet Metal Workers Union',
#  'Franklin Resources',
#  'Garfunkel Wild PC',
#  'Neal & Co',
#  'Adams & Reese',
#  'USAA',
#  'Rock Management Group Ltd',
#  'York Risk Services Group',
#  'Duke University',
#  'Intellectual Ventures LLC',
#  'Steptoe & Johnson',
#  'Copart Inc',
#  'Qualico Steel',
#  'JH Land LLC',
#  'Jackson Kelly Pllc',
#  'Miller & Martin',
#  'Rountree, Losee & Baldwin',
#  'Alex Lee Inc',
#  'Technology Crossover Ventures',
#  'Freeport-McMoRan',
#  'Integral Manufacturing',
#  'Sandersville Railroad',
#  'Cole, Schotz et al',
#  'Big Game Capital',
#  'Mp Biomedicals',
#  'Baupost Group',
#  'Demmer Corp',
#  'GHG Corp',
#  'Campolo, Middleton & McCormick',
#  'American Waterways Operators',
#  'Windway Capital',
#  'American Podiatric Medical Assn',
#  'Dorsey & Whitney',
#  'Preit',
#  'INTRUST Bank',
#  "George O'Neill",
#  'Pain Medicine Assoc',
#  'Joel M Weissman PA',
#  'Young, Conaway et al',
#  'Rli Corp',
#  'Costas Provisions',
#  'Halliburton Co',
#  'Midland Surgical Assoc',
#  'Deloitte LLP',
#  'Democratic Party of New York',
#  'Bluestem Capital',
#  'RW Allen LLC',
#  'Ultimate Fighting Championship',
#  'Paul, Weiss Et Al',
#  'Affiliated Managers Group',
#  'Edens & Avant',
#  'Kroger Co',
#  'Debevoise & Plimpton',
#  "Smith's Inc",
#  'John S Fund',
#  'Cerberus Capital Management',
#  'Berger Singerman PA',
#  'Credit Union National Assn',
#  'Impact',
#  'Kaiser Permanente',
#  'Susman Godfrey LLP',
#  'L-3 Communications',
#  'Simon Property Group',
#  'United Food & Commercial Workers Union',
#  'Doll Distributing',
#  'Huntington Ingalls Industries',
#  "Frontline Homeowner's Insurance",
#  'University of Notre Dame',
#  'Ciciora Custom Homes',
#  'College Loan Corp',
#  'FRS Capital Corp',
#  'National Marine Manufacturers Assn',
#  'Collier Investments',
#  'Link Group',
#  'National Beer Wholesalers Assn',
#  'American Society of Interventional Pain Physicians',
#  'Tuesday Group PAC',
#  'Elbit Systems',
#  'University of Arizona',
#  'Armour Properties',
#  'Toshiba Corp',
#  'Kennedy-sinema Victory Fund',
#  'Harvard University',
#  'Mason Capital Management',
#  'AFL-CIO',
#  'Fluor Corp',
#  'Ck Holdings',
#  'Ameren Corp',
#  'Coca-Cola Co',
#  'American College of Cardiology',
#  'Fincantieri-Cantieri Navali Italiani SpA',
#  'Eckert, Seamans et al',
#  'Projects Unlimited',
#  'Intl Brotherhood of Electrical Workers',
#  'Charles Barker Automotive',
#  'Richard & Barbara Gaby Foundation',
#  'Holekamp Capital',
#  'Arnold & Porter Kaye Scholer',
#  'Educational Playcare',
#  'Quirk Auto',
#  'National Business Aircraft Assn',
#  'American Assn of Orthodontists',
#  'AFLAC Inc',
#  'Zurich Financial Services',
#  'Santo Petroleum',
#  'TCF Financial',
#  'FMC Technologies',
#  'PG&E Corp',
#  'Total Quality Logistics',
#  'Spirit Aerosystems',
#  'Right to Life',
#  'Bank Of America',
#  'Roche Constructors',
#  'AG Hill Partners',
#  'WNY Board of Ed',
#  'LDI Ltd',
#  'Robson Co',
#  'Innovative Defense Technologies',
#  'Kleiner, Perkins et al',
#  'NVR Inc',
#  'Rock N Jk Farms',
#  'Royal Automotive Group',
#  'Early, Lucarelli et al',
#  'Datron World Communications',
#  'Ocean Champions',
#  'Calpine Corp',
#  'American Hotel & Lodging Assn',
#  'Water Valley Land Co',
#  'Dartmouth-Hitchcock Medical Center',
#  'Auld Investments',
#  'Rockwell Collins Inc',
#  'Georgia Society of Interventional Pain P',
#  'Switch Supernap',
#  'Barron Collier Companies',
#  'SPS Studios',
#  'Pierce Atwood LLP',
#  'Rooney Holdings',
#  'Granville Homes',
#  'Windstream Communications',
#  'TAMKO Building Products',
#  'National Assn Of Broadcasters',
#  'Mackenzie Capital Management',
#  'Hartford Financial Services',
#  'Smart Pharmacy',
#  'Machinists/Aerospace Workers Union',
#  'Cash Express LLC',
#  'GOJO Industries',
#  'Campbell Soup',
#  'Highland Engineering',
#  'GenCorp Inc',
#  'Robins, Kaplan et al',
#  'University of Michigan',
#  'University of Maryland',
#  'Anschutz Corp',
#  'Mid Manhattan PAC',
#  'Lockheed Martin',
#  'National League of Postmasters',
#  'Silver Lake Partners',
#  'Peter G Peterson Foundation',
#  'JPMorgan Chase & Co',
#  'Deseret International Forwarding',
#  'Covelli Enterprises',
#  'Comcast Corp',
#  'Arrow United Investment',
#  'Ross, Feller & Casey',
#  'Virginia Urology',
#  'Jones Day',
#  'Aircraft Owners & Pilots Assn',
#  'American Pilots Assn',
#  'Ischemix',
#  'STV Group',
#  'Edison Electric Institute',
#  'US Dept of Health & Human Services',
#  'Batavia Enterprises',
#  'Oracle Corp',
#  'City Light & Power',
#  'Jenner & Block',
#  'ICI Homes',
#  'Mack-Cali Realty',
#  'Association for Advanced Life Underwriting',
#  'Nimeks Organics',
#  'Harbor Freight Tools',
#  'Tri-Cities Skin & Cancer',
#  'Wachtell, Lipton et al',
#  'Leadership that Listens PAC',
#  'Scana Corp',
#  'Nustar Energy',
#  'American Nurses Assn',
#  'Hurt, Norton & Assoc',
#  'Entrepreneurial Corp Group',
#  'Baker, Donelson et al',
#  'Citizens First Bank',
#  'National Apartment Assn',
#  'YAU Therapeutics',
#  'Venable LLP',
#  'MAH Inc',
#  'Skadden, Arps et al',
#  'Textron Inc',
#  'Energex Corp',
#  'Crystal Run Healthcare',
#  'Saban Capital Group',
#  'Gibson, Dunn & Crutcher',
#  'Foundation Medicine',
#  'For Adult Industry Responsibility Commit',
#  'Cablevision Systems',
#  'Susan B Anthony List',
#  'Archegos Capital Management',
#  'Conklin Co',
#  'Bancorpsouth',
#  'Home Depot',
#  'Ecolab Inc',
#  'M Resort LLC',
#  'Radio One',
#  'Kirby Corp',
#  'Center Point Inc',
#  'Western Rim Properties',
#  'Prudential PLC',
#  'Eye of the Tiger PAC',
#  'Marble Bridge Funding Group',
#  'Partners HealthCare',
#  'National Air Traffic Controllers Assn',
#  'Ftc',
#  'Humane Society of the US',
#  'John Bolton PAC',
#  'Sheet Metal/AC Contractors Assn',
#  'United Technologies',
#  'Acadia Healthcare',
#  'Common Values PAC',
#  'National Assn of Letter Carriers',
#  'American Dental Assn Political Ac',
#  'Jenzabar Inc',
#  'Reclaim America PAC',
#  'Fairfax County, VA',
#  'Johns Hopkins University',
#  'Bob Ciasulli Auto Group',
#  'Texas Timberjack',
#  'AES Corp',
#  'Omni New York',
#  'Royce Victory Fund',
#  'Faegre Baker Daniels',
#  'Mortgage Bankers Assn',
#  'Wells Real Estate Funds',
#  'Mana Products',
#  'Salt River Project',
#  'Vectren Corp',
#  'Mr Stax',
#  'Centerbridge Partners',
#  'Pointer Management',
#  'American Subcontractors Assn',
#  'University of Hawaii',
#  'American Trucking Assns',
#  'Pts Tax',
#  'Aronov Realty Management',
#  'Exoxemis Inc',
#  'Carroll Companies',
#  'Foundry Group',
#  'Metlife Inc',
#  'Foley Hoag LLP',
#  'American Electric Power',
#  'Independent Petroleum Assn of America',
#  'Astrophysics Inc',
#  'G&C Autobody',
#  'Lea County State Bank',
#  'Morris & Dickson',
#  'Knapheide Manufacturing',
#  'Applied Business Concepts',
#  'Advocare International',
#  'Bartlett & Co',
#  'Engineering Micro Research Inc',
#  'Schneider National',
#  "Land O'Lakes",
#  'Bryan Cave LLP',
#  'Prime Inc',
#  'Cmg Management',
#  'Van Scoyoc Assoc',
#  'Edwards Wildman Palmer',
#  'Fanjul Corp',
#  'Talbot Insurance & Financial',
#  'Anderson Trucking Services',
#  'Dykema Gossett',
#  'Valley Cardiology',
#  'VGM Group',
#  'Capital Corp',
#  'Bollinger Shipyards',
#  'Nixon Peabody LLP',
#  'Wall-Snow Realty',
#  'Cisco Systems',
#  'Stroock, Stroock & Lavan',
#  'Piping Rock Health Products',
#  'Pilot Corp',
#  'TC Jacoby & Co',
#  'Wilbur Smith Law Firm',
#  'Telapex Inc',
#  'Charles Ingram Lumber',
#  'Enervest Ltd',
#  'Price Companies',
#  'Iowa Select Farms',
#  'Nucor Corp',
#  'Hasten Bancshares',
#  "Cozen O'Connor",
#  'Leidos Inc',
#  'State of North Carolina',
#  'Park Circle Investments',
#  'Brewers Dist Co',
#  'Capital Group Companies',
#  'AbbVie Inc',
#  'Citigroup Inc',
#  'Constellation Brands',
#  'Sempra Energy',
#  'DCI Group',
#  'Intelligenesis',
#  'Eisai Co Ltd',
#  'Hawaiian Electric Industries',
#  'CSX Corp',
#  'Related Companies',
#  'Hoosiers First PAC',
#  'Defend America PAC',
#  'Lockridge Grindal Nauen PLLP',
#  'Bb&T Corp',
#  'Fresenius Medical Care',
#  'Woodward Inc',
#  'MLB Consulting',
#  'League of Conservation Voters',
#  'Advanced Integrated Technologies LLC',
#  'Girardi & Keese',
#  'Balch & Bingham',
#  'Apercen Partners',
#  'Banc First',
#  'Xenex Disinfection Services',
#  'Ocean Shipholdings',
#  'Cantor Fitzgerald',
#  'Oaktree Capital Management',
#  'UNITE HERE',
#  'Lucas Oil Products',
#  'Q2 Holdings',
#  'Cheniere Energy',
#  'Peninsula PAC',
#  'White Castle System',
#  'Wilmorite Inc',
#  'Amarillo National Bank',
#  'Henry Resources',
#  'MCNA Dental Plans',
#  'Moyle Petroleum',
#  'Milestone Electric',
#  'Michigan Industrial Tools',
#  'Roche Holdings',
#  'Anna Hu LLC',
#  'Haggard Law Firm',
#  'Waterson Terminal Services',
#  'R&L Brosamer',
#  'Amalgamated Transit Union',
#  'Acorn Campus Ventures',
#  'CoreCivic Inc',
#  'Valero Energy',
#  'Sos Global Express',
#  '3M Co',
#  'Natural Food Source Inc',
#  'Heartland Values PAC',
#  'Royal Palm Academy',
#  'Broadcasting Media Partners',
#  'Holland Partners',
#  'Phipps Anderson Deacon Llp',
#  'Essex Meadows',
#  'Medical Assoc of Brevard',
#  'Keller Investment Properties',
#  'American United Life Insurance',
#  'International Longshoremens Assn',
#  'Community Oncology Alliance',
#  'Cubic Energy',
#  'Crow Holdings',
#  'Silveus Insurance Group',
#  'Beef Products Inc',
#  'Golden Age Farm',
#  'Nightingale Home Healthcare',
#  'Royal Business Bank',
#  'Seafarers International Union',
#  'American Psychiatric Assn',
#  'Professional Compounding Centers of America',
#  'Netflix Inc',
#  'Hendrick Automotive',
#  'Hallmark Cards',
#  'Conference America',
#  'New Breed Logistics',
#  'Grimmway Farms',
#  'AREVA Group',
#  'Agree Realty',
#  'Bank of America',
#  'Brotherhood of Locomotive Engineers',
#  'Maynard, Cooper & Gale',
#  'Continental Pacific',
#  'Weststar Bank',
#  'L Brands',
#  'SAS Institute',
#  'University of Iowa',
#  'Florida Cancer Specialists',
#  'Full Sail',
#  'National Independent Automobile Dealers',
#  'American Frozen Food Institute',
#  'Norene Ranches',
#  'Creative Assoc International',
#  'Allstate Insurance',
#  'Unitedhealth Group',
#  'Anderson Columbia Co',
#  'Law Offices of Peter G Angelos',
#  'Painters & Allied Trades Union',
#  'Total Military Management',
#  'KKR & Co',
#  'Kennedy Group',
#  'Baycare Physicians PAC',
#  'Mesirow Financial',
#  'SpaceX',
#  'Calvary Hospital',
#  'Cigna Corp',
#  'Massachusetts Institute of Technology',
#  'Humana Inc',
#  'General Communication Inc',
#  'Reynolds American',
#  'McKesson Corp',
#  'Bancroft Investments',
#  'Ironworkers Union',
#  'Morgan Stanley',
#  'National Assn of Real Estate Investment Trusts',
#  'Willis Group Holdings',
#  'Chevron Corp',
#  'Capital Group',
#  'Artery Capital Group',
#  'Src Sales & Marketing',
#  'Big Time Products',
#  'CB Nanda & Assoc',
#  'Masimo Corp',
#  'Meta Housing Corp',
#  'Peace Action',
#  'Jackson Hole Mountain Resort',
#  'At&T Inc',
#  'White Mountains Insurance Group',
#  'Heartland Realty Investors',
#  'Aero Metals',
#  'Hanning & Bean Enterprises',
#  'Bernstein Companies',
#  'State Street Corp',
#  'Brown & Brown Insurance',
#  'Fairfield Auto Group',
#  'WilmerHale Llp',
#  'SunTrust Banks',
#  'Dow Chemical',
#  'Maclean-Fogg Co',
#  'Bracey Supermarkets',
#  'Gci',
#  'Lions Gate Entertainment',
#  'Peirson & Patterson',
#  'Minnesota Ltd',
#  'Veterans United Home Loans',
#  'Communications Workers of America',
#  'North Carolina Leadership Fund',
#  'Entergy Corp',
#  'Mbi Energy Services',
#  'Textile Rubber & Chemical Co',
#  'US Bancorp',
#  'Royal Brush Manufacturing',
#  'Knight Hawk Coal',
#  'Leonardo-Finmeccanica',
#  'BGC Partners',
#  'Bricklayers Union',
#  'KPMG LLP',
#  'Jones Financial Companies',
#  'Morgan Lewis LLP',
#  'Chemorse Ltd',
#  'Cason Timber & Cattle Co',
#  'Sentry Insurance',
#  'Steris Corp',
#  'Janus Research',
#  'Edison International',
#  'Woodbridge Structured Funding',
#  'Brown Rudnick LLP',
#  'Hunton & Williams',
#  'Drinker, Biddle & Reath',
#  'Yellowstone Bank',
#  'JStreetPAC',
#  'Marvin Windows',
#  'University of Miami',
#  'Pain Management Clinic',
#  'Directors Guild of America',
#  'American Medical Assn',
#  'Continental Properties',
#  'S Abraham & Sons',
#  'Sutherland Capital Management',
#  'Carl Weinberg & Co',
#  'National Amusements Inc',
#  'Western Mutual Insurance',
#  "Wendy's Co",
#  'Butler Amusements',
#  'Chubb INA',
#  'Free State PAC',
#  'Orscheln Group',
#  'Charah Inc',
#  'Society of Interventional Radiology',
#  ...}

# %%
#another way:
contrib_nodes = [node for node in G.nodes() if node not in leg_nodes]

# %%
contrib_nodes
# Out:
# ['Biloxi Freezing & Processing',
#  'Fannie Mae',
#  'Emergency Medicine Consultants',
#  'Lozier Corp',
#  'McMl PA',
#  'Bridge Capital',
#  'Saltchuk Resources',
#  'Express Scripts',
#  'Transport Workers Union',
#  'Welsh, Carson et al',
#  'Gershow Recycling',
#  'United Transportation Union',
#  'WPP Group',
#  'Fragomen, Del Rey et al',
#  'Ozarks Coca-Cola',
#  'Cajun Industries',
#  'American Council of Engineering Cos',
#  'Boilermakers Union',
#  'Teamsters Union',
#  'New Balance Athletic Shoe',
#  'American Federation of Teachers',
#  'Forhan Co',
#  'Majestic Realty',
#  'Berry Investments',
#  'Zions Bancorp',
#  'Hagan, Noll & Boyle',
#  'Archer & Greiner',
#  'Batavia Enterprises',
#  "Richie's Specialty Pharmacy",
#  'Deere & Co',
#  'Conklin Co',
#  'General Dynamics',
#  'Pisces Inc',
#  'Crowe Horwath LLP',
#  'Astrophysics Inc',
#  'Hensel Phelps Construction',
#  'Freedom Project',
#  'American Peanut Shellers Assn',
#  'American Bankers Assn',
#  'Soros Fund Management',
#  'Innovative Defense Technologies',
#  'American Subcontractors Assn',
#  'Alro Steel',
#  'Pacers Sports & Entertainment',
#  'Agio International',
#  'Charah Inc',
#  'Boston Scientific Corp',
#  'Caesars Entertainment',
#  'Senior Star Living',
#  'Jazz Pharmaceuticals',
#  'Bremen Castings',
#  'McDowell Enterprises',
#  'Keyes Automotive Group',
#  'Alexander & Baldwin',
#  'Topspin Partners',
#  'Democrats Time In Nevada',
#  'Knight Transportation',
#  'Granville Homes',
#  'UnitedHealth Group',
#  'New Breed Inc',
#  'Stevens & Lee',
#  'Crow Holdings',
#  'American Pharmacists Assn',
#  'Switch Supernap',
#  'Adams Robinson Enterprises',
#  'Impact Plastics',
#  'Ernst & Young',
#  'Council of Insurance Agents & Brokers',
#  'Anderson Trucking Services',
#  'Alkermes Plc',
#  'Blue Cross/Blue Shield',
#  'Alston, Hunt et al',
#  'Simmons First National',
#  'Terra Linda Farms',
#  'Marcus & Millichap',
#  'Harbert Management',
#  'Texas A&M University',
#  'Prestage Farms',
#  'Operating Engineers Union',
#  "St George's University",
#  'Harris Corp',
#  'Kleiner, Perkins et al',
#  'Visa Inc',
#  'Desert Caucus',
#  'Fanjul Corp',
#  'Primerica Inc',
#  'US Senate',
#  'Forsyth Plastic Surgery',
#  'US Bancorp',
#  'Bancorpsouth',
#  'Wolverine Gas & Oil',
#  'Wall-Snow Realty',
#  'GMS Mine Repair & Maintenance',
#  'Mansour Co',
#  'Corporate Capital LLC',
#  'Nibco Inc',
#  'Capital Group',
#  'National Assn of Home Builders',
#  'NCTA The Internet & Television Assn',
#  'American College of Surgeons',
#  'National Alliance of Forest Owners',
#  'United Contractors Midwest',
#  'Plainscapital Corp',
#  'First Bank',
#  'Blessey Marine Service',
#  "National Cattlemen's Beef Assn",
#  'Facebook Inc',
#  'All American Asphalt',
#  'College Loan Corp',
#  'Leonardo-Finmeccanica',
#  'Re/Max International',
#  'Cerberus Capital Management',
#  'Mantech International',
#  'Apollo Global Management',
#  'Drinker, Biddle & Reath',
#  'Capital Corp',
#  'National Electrical Contractors Assn',
#  'Georgetown University',
#  'Frontera Resources',
#  'Rock Management Group Ltd',
#  'Act for Entertainment',
#  'Park Ohio Holdings',
#  'Kaitar Resources',
#  'Cronley Construction Co',
#  'Hess Corp',
#  'American Financial Group',
#  'Rain & Hail Insurance Society',
#  'Silver Lake Partners',
#  'Nutramax Laboratories',
#  'Texas Star Investments',
#  'GST Inc',
#  'American Assn of Crop Insurers',
#  'American Trucking Assns',
#  'Western Mutual Insurance',
#  'Kojaian Companies',
#  'Medico Industries',
#  'Portland General Electric',
#  'University of Washington',
#  'Genesis 10',
#  'Brown Rudnick Llp',
#  'American Society of Travel Agents',
#  'First Premier Bank',
#  'Eli Lilly & Co',
#  'AFLAC Inc',
#  'Genworth Financial',
#  'Citadel LLC',
#  'National Ready Mixed Concrete Assn',
#  'Woodward Inc',
#  'AECOM Global',
#  'National Rural Electric Cooperative Assn',
#  'Paul, Weiss et al',
#  'Pinnacle West Capital',
#  'Oriental Financial Group',
#  'Continental Properties',
#  'Good Stuff Fishing LLC',
#  'Silvercrest Asset Management',
#  'Kenan Advantage Group',
#  'Carlyle Group',
#  'Sv Angel LLC',
#  'ACA International',
#  'Novogradac & Co',
#  'BNP Paribas',
#  'Pivotal Group',
#  'Western National Group',
#  'Service Employees International Union',
#  'Sanford Health',
#  'Arizona Diamondbacks/Datatel Inc',
#  'Tenax Aerospace',
#  'Regeneron Pharmaceuticals',
#  'Clear',
#  'Northrop Grumman',
#  'Society of Interventional Radiology',
#  'Independent Community Bankers of America',
#  'McWane Inc',
#  'Central Pacific Financial',
#  'WPX Energy',
#  'Silver Eagle Distributors',
#  'Murphy Endeavors',
#  'Islands Mechanical',
#  'DANPAC',
#  'Connolly Coastal Capital',
#  'Blue Diamond Growers',
#  'Brown Brothers Harriman & Co',
#  'B&G Food Enterprises',
#  'TeleCommunication Systems Inc',
#  'Impact',
#  'Peninsula PAC',
#  'John Bolton PAC',
#  'Moveon.org',
#  'Schahet Hotels',
#  'Integral Manufacturing',
#  'Kobayashi, Sugita & Goda',
#  'Avenue Ventures',
#  'Casaca Vineyards',
#  'Icee Distributors',
#  'Farm Credit Council',
#  'Paul Rogers & Assoc',
#  'Xana Management',
#  'Baupost Group',
#  'Dykema Gossett',
#  'BASF SE',
#  'DuPont Co',
#  'Holtec International',
#  'Scentsy',
#  'Womencount PAC',
#  'American Society of Anesthesiologists',
#  'SEAKR Engineering',
#  'Chicago Bridge & Iron',
#  'Harbor Freight Tools',
#  'Verizon Communications',
#  'Ibm',
#  'American Crystal Sugar',
#  'Musical Instruments Museum',
#  'AVT Ventures',
#  'Mednax Inc',
#  'United Food & Commercial Workers Union',
#  'Peabody Energy',
#  'Campbell Companies',
#  'Target Corp',
#  'Willis Group Holdings',
#  'National Community Pharmacists Assn',
#  'Ted Poe for Congress',
#  'Koskoff, Koskoff & Bieder',
#  'McWilliams Government Affairs',
#  'Huntington Ingalls Industries',
#  'Liberty Media',
#  'Chickasaw Nation',
#  'GOJO Industries',
#  'Devon Energy',
#  'Duane Morris LLP',
#  'Boeing Co',
#  'Everglades College',
#  'Rely on Your Beliefs',
#  'Link Group',
#  'Johns Hopkins University',
#  'Nucor Corp',
#  'Humane Society of the US',
#  'Varischetti & Sons',
#  'American Lighting Assn',
#  'General Communication Inc',
#  'Phipps Anderson Deacon Llp',
#  'RJ Corman Railroad Group',
#  'Xcel Energy',
#  'Mtsu',
#  'Knight Hawk Coal',
#  'HECK YES! VICTORY FUND',
#  'Peachtree Orthopaedic Clinic',
#  'Goldsboro Milling',
#  'House Liberty Fund',
#  'Smart Pharmacy',
#  'Circle Packaging Machinery',
#  'Ruan Companies',
#  'Gideon, Cooper & Essary',
#  'Credit Suisse Group',
#  'TPG Capital',
#  'Miller & Martin',
#  'Sandlapper Securities',
#  'Federated Investors Inc',
#  'COLE PAC',
#  'Oberlin College',
#  'Principal Financial Group',
#  'Cdi',
#  'Indiana University',
#  'Worldwide Language Resources',
#  'Ozark Mountain Poultry',
#  'Federation of American Hospitals',
#  'Susman Godfrey LLP',
#  'Salopek 6u Farms',
#  'Votesane PAC',
#  'Scranton Label Inc',
#  'Banc First',
#  'PCC/Customs Brokers & Freight Forwarders',
#  'Microsoft Corp',
#  'Monsanto Co',
#  'Aloha Partners',
#  'General Electric',
#  'Calvi Electric',
#  'Marriott International',
#  'Jenzabar Inc',
#  'Betz Industries',
#  'Harvard University',
#  'Costas Provisions',
#  'Exelon Corp',
#  'Amway/Alticor Inc',
#  'Fairfax County, VA',
#  'Marshfield Clinic',
#  'Keller Investment Properties',
#  'Boston University',
#  'Virginia Urology',
#  'Magnus Pacific',
#  'Dannenbaum Engineering',
#  'Allen Morris Co',
#  'National Multi Housing Council',
#  'Aitken, Aitken & Cohn',
#  'Financial Service Centers of America',
#  'Calvary Hospital',
#  'Lockheed Martin',
#  'Covelli Enterprises',
#  'Computer Sciences Corp',
#  'Atco Investment',
#  'Regional Urology',
#  'Maurer & Scott Sales',
#  'Marsh & McLennan',
#  'Nuclear Energy Institute',
#  'SF Investments',
#  'News Corp',
#  'Research Affiliates LLC',
#  'Jennmar Corp',
#  'Mylan Inc',
#  'Mockler Beverage',
#  'Cancer Treatment Centers of America',
#  'Friends Of David Schweikert',
#  'Alliance Resource Partners',
#  'Intellectual Ventures LLC',
#  'Russell Stover Candies',
#  'National Assn of Truck Stop Operators',
#  'Cook Group',
#  'Hartford Financial Services',
#  'National Auto Dealers Assn',
#  'American Assn for Justice',
#  'Prudential Financial',
#  'Ag Services',
#  'Cablevision Systems',
#  'Comerica Inc',
#  'Southwestern Co',
#  'Ocean Shipholdings',
#  'Alliant Techsystems',
#  'Brady for Congress',
#  'Dow Chemical/Corning',
#  'Foundation Medicine',
#  "Bracey's Supermarkets",
#  'Trident Seafoods',
#  'ConocoPhillips',
#  'Preston Development',
#  'Precision Paper & Board',
#  'Ultra Electronics',
#  'Advanced Integrated Technologies LLC',
#  'LDI Ltd',
#  'Kennedy-sinema Victory Fund',
#  'Masimo Corp',
#  '3M Co',
#  'Barnes & Thornburg',
#  'Bradley, Arant et al',
#  'Crawford Group',
#  'Newport Orthopedic Institute',
#  '1st Family Dental',
#  'KPMG LLP',
#  'Bb&T Corp',
#  'Agree Realty',
#  'Prime Inc',
#  'Element Electronics',
#  'Air Products & Chemicals Inc',
#  'Lathrop & Gage',
#  'Shaheen & Gordon',
#  'Pioneer Nursery',
#  'Keating, Muething & Klekamp',
#  'Transtelco',
#  'Hantz Group',
#  'Simpson, Thacher & Bartlett',
#  'World Wide Technologies',
#  'Stronghold Engineering',
#  'Imaging Assoc of N Ms',
#  'Simmons Hanly Conroy',
#  'Early, Lucarelli et al',
#  'Acadia Healthcare',
#  'San Manuel Band of Mission Indians',
#  'Home Depot',
#  'Oaktree Capital Management',
#  'Pelco Structural',
#  'Matson Inc',
#  'Cisco Systems',
#  'Textron Inc',
#  'Carroll Companies',
#  'Broadway National Bank',
#  'Voices for Progress',
#  'Hart Group',
#  'AEGON NV',
#  'Thornton Law Firm',
#  'Bowdoin College',
#  'Ashland Inc',
#  'BP',
#  "EMILY's List",
#  'Red Apple Group',
#  'Edison Chouest Offshore',
#  'CMS Energy',
#  'Langlas & Assoc',
#  'Crosby Tugs',
#  'Woodbranch Investments',
#  'Windstream Communications',
#  'Coughlin Construction',
#  'Forest City Enterprises',
#  'Ewing Constructions Co',
#  'BB&T Corp',
#  'Enervest Ltd',
#  'Akerman LLP',
#  'Committee for Hispanic Causes-BOLD PAC',
#  'Cooks Pest Control',
#  'Kiewit Corp',
#  'Collier Investments',
#  'Codina Group',
#  'Rudin Management',
#  'Briggs & Stratton',
#  'Chartwell Hotels',
#  'Cronin, Fried et al',
#  'National HealthCare Corp',
#  'International Paper',
#  'National Stone, Sand & Gravel Assn',
#  'Intl Alliance Theatrical Stage Employees',
#  'Fisher Investments',
#  'Rubin & Rudman',
#  'Belmark Inc',
#  'Harbour Group Industries',
#  'Zurich Financial Services',
#  'Eberstein & Witherite',
#  'Sugar Creek Packing',
#  'Defend America PAC',
#  'Gci',
#  'Home Creations',
#  'North Shore Hematology Oncology Assoc',
#  'Kinder Morgan Inc',
#  'Saker ShopRites',
#  'DeRoyal Industries',
#  'Consol Energy',
#  'Willkie, Farr & Gallagher',
#  'Cemco Inc',
#  'Susan B Anthony List',
#  'Bank of America',
#  'QTC Management',
#  'American Pilots Assn',
#  'FMC Technologies',
#  'Gross Builders',
#  'Nustar Energy',
#  'Ward & Smith',
#  'Fun Spot of Florida LLC',
#  'Kirby Corp',
#  'George Peck & Assoc, Plc',
#  'Power, Rogers & Smith',
#  'Datron World Communications',
#  'Seacoast Commerce Bank',
#  'Pcca',
#  'Law Offices of Jeremy D, Weinsttein',
#  'Perkins Coie',
#  'Applied Business Concepts',
#  'Arbor Homes',
#  'Polsinelli PC',
#  'Capital Funding Group',
#  'CGCN Group',
#  'WilmerHale Llp',
#  'McCoy Group',
#  'For Adult Industry Responsibility Commit',
#  'Capital One Financial',
#  'Bechtel Group',
#  'Coalition for Student Success',
#  'Omni New York',
#  'Harrison, White et al',
#  'Alabama Farmers Federation',
#  'Intelsat Holdings',
#  'University of Arizona',
#  'Pierce Atwood LLP',
#  'Laborers Union',
#  'Envirosep',
#  'Senate Conservatives Fund',
#  'Akt Development',
#  'Southern Co',
#  'Amalgamated Transit Union',
#  'New Hampshire Steel',
#  'Case Western Reserve University',
#  'Aero Metals',
#  'Powell Construction',
#  'American Podiatric Medical Assn',
#  'Right to Life',
#  'Sutherland Capital Management',
#  'TIAA',
#  'Pain Medicine Assoc',
#  'American Seniors Housing Assn',
#  'University of New Mexico',
#  'Truman Arnold Companies',
#  'International Longshoremens Assn',
#  '4Life Research',
#  'Island Doctors',
#  'Gregory Rockhouse Ranch',
#  'State of Illinois',
#  'Cvjh LLC',
#  'Wynn Resorts',
#  'Mmr Constructors',
#  'Santo Petroleum',
#  'SPS Studios',
#  'Americans for the Arts',
#  'Metlife Inc',
#  'Idacorp Inc',
#  'Crane & Sons',
#  'American Development Corp',
#  'American Hotel & Lodging Assn',
#  'Brunswick Corp',
#  'Kingston Technology',
#  'American Postal Workers Union',
#  'Husch Blackwell LLP',
#  'American Kidney Stone Management',
#  'Hy-Vee Inc',
#  'Holland Partners',
#  'Royal Palm Academy',
#  'Conner, Strong & Buckelew',
#  'Machinists/Aerospace Workers Union',
#  'Cooney & Conway',
#  'University of Montana',
#  'Law Offices of Regina J Roger',
#  'Barnes & Noble',
#  'Bryan Cave LLP',
#  'King Capital',
#  'Total Military Management',
#  'Chemorse Ltd',
#  'Cypress Real Estate Advisors',
#  'Air Line Pilots Assn',
#  'Richard Childress Racing',
#  'Yale University',
#  'Unum Group',
#  'Kaiser Permanente',
#  'Wachtell, Lipton et al',
#  'Davidson Kempner Capital Management',
#  'Noble Energy',
#  'Millard Group',
#  'Cronin Group',
#  'Majority Cmte PAC',
#  "Love's Travel Stops",
#  'Liquid Environmental Solutions',
#  'Mid Manhattan PAC',
#  'Rock Holdings',
#  'United Continental Holdings',
#  'Kroger Co',
#  'TCF Financial',
#  'UBS AG',
#  'Jelly Belly Candy',
#  'Servpro Industries',
#  'Wells Blue Bunny',
#  'National Healthcare Corp',
#  'Warland Investments',
#  'Jones Day',
#  "Katie's Seafood Market",
#  'Suburban Collection',
#  'Vanir Development',
#  'Norene Ranches',
#  'Astenbeck Capital Management',
#  'James E Hall',
#  'Kindred Healthcare',
#  'Lindy Paving',
#  'Ariel Corp',
#  'Healthmark Ventures',
#  'Squire Patton Boggs',
#  'Sanderson Farms',
#  'Allegiancy',
#  'Hawkins Construction',
#  'CEMEX SA de CV',
#  'Hendrick Automotive',
#  'University of Notre Dame',
#  'Burns & McDonnell',
#  'Field Fresh Foods',
#  'South Texas Renal Care Group',
#  'Consumer Technology Assn',
#  'Wexford Capital',
#  'University of Hawaii',
#  'Center Point Inc',
#  'Onyx Collection',
#  'Navistar International',
#  'Making America Prosperous',
#  'Roche Holdings',
#  'Bobby Cox Companies',
#  'Globe University',
#  'USAA',
#  'American Academy of Dermatology Assn',
#  'Ischemix',
#  'PCS Wireless',
#  'Rex American',
#  'Tenaska Energy',
#  'National Rural Letter Carriers Assn',
#  'AmeriPAC: The Fund for a Greater America',
#  'Pan Am Equities',
#  'Princeton University',
#  'Bates Amusements',
#  'Oregon Health & Science University',
#  'Peninsula Capital Advisors',
#  'CoreCivic Inc',
#  'Kitco Fiber Optics',
#  'Resort Group',
#  'Global Partners LP',
#  'Bernstein Shur',
#  'Strategic Growth Bank',
#  'Big Time Products',
#  'Berkshire Partners',
#  'TC Jacoby & Co',
#  'Credit Union National Assn',
#  'Marvin Windows',
#  'ICI Homes',
#  'Maclean-Fogg Co',
#  'Barron Collier Companies',
#  'American Resort Development Assn',
#  'United Mine Workers of America',
#  'Akonadi Foundation',
#  'Balch & Bingham',
#  'Rent-A-Center',
#  'AG Hill Partners',
#  'Amazon.com',
#  'Kirkham Motorsports',
#  'The Villages',
#  'North Star Companies',
#  'Kennedy Group',
#  'Reed Smith LLP',
#  'Eaton Corp',
#  'Mitchell Automotive Group',
#  'Dorsey & Whitney',
#  'Asplundh Tree Expert Co',
#  'Ocean Riders Engineering',
#  'Hunt Companies',
#  'Cubic Energy',
#  'M Resort LLC',
#  'University of Colorado',
#  'Eugene Lee Inc',
#  'Apollo Education Group',
#  'Daybrook Fisheries',
#  'Radiance Technologies',
#  'Sandersville Railroad',
#  'At&T Inc',
#  'NRP Group',
#  "O'Brien, Gentry & Scott",
#  'Toshiba Corp',
#  'Avant Inc',
#  'Maschhoffs',
#  'Campbell Soup',
#  "Southern Glazer\\'s Wine & Spirits",
#  'Alkermes plc',
#  'Ball Homes',
#  'Robbins, Geller et al',
#  'US Grid Co',
#  'Hy Rock Excavation',
#  'Kutak Rock LLP',
#  'Baskerville-Donovan Inc',
#  'American Assn/Oral & Maxillofacial Surg',
#  'Sandhills Publishing',
#  'Dynetics Inc',
#  'Washington University In St Louis',
#  'Veterans United Home Loans',
#  'Vorys, Sater et al',
#  'USA Rice Federation',
#  'Mintz, Levin et al',
#  'Kmg Tool',
#  'Leggett & Platt',
#  'Brilex Industries',
#  'Bracey Supermarkets',
#  'Lea County State Bank',
#  'Charter Brokerage LLC',
#  'Comcast Corp',
#  'Norfolk Southern',
#  'Duane Morris Llp',
#  'SpaceX',
#  'PVS Chemicals',
#  'McVean Trading & Investments',
#  'Fred Haas Toyota Country',
#  'Sinclair Companies',
#  'Conway Mackenzie',
#  'CME Group',
#  'Allstate Insurance',
#  'Liberty Mutual',
#  'Edison Electric Institute',
#  'Texas Timberjack',
#  'Rountree, Losee & Baldwin',
#  'Abbott Laboratories',
#  'American University of Antigua',
#  'VGM Group',
#  'Apple Inc',
#  'Fisher Barton Group',
#  'Wellmont',
#  'Terral River Service',
#  'Yellowstone Bank',
#  'Southeastern Minerals',
#  'Highfields Capital Management',
#  'Meta Housing Corp',
#  'McDermott, Will & Emery',
#  'Haury & Smith Contractors',
#  'American Academy of Pediatric Dentistry',
#  'American Academy of Neurology',
#  'Western Oilfields Supply',
#  'Quirk Auto',
#  'Barrack, Rodos & Bacine',
#  'Graham Companies',
#  'Aetna Inc',
#  'Willoughby & Hoefer',
#  'Humana Inc',
#  'Butler Amusements',
#  'Digital Canal Corp',
#  'Hackman Capital Partners',
#  'Big Game Capital',
#  'Leidos Inc',
#  'Genesee & Wyoming',
#  'Cgs Services',
#  'Zivity LLC',
#  'English Lloyd & Armenta',
#  'Cops Monitoring',
#  'Johnson City Medical Center',
#  'United Technologies',
#  'Seafarers International Union',
#  'Park Circle Investments',
#  'Cheniere Energy',
#  'Drummond Co',
#  'Tulsa Bone & Joint',
#  'Hfr Design',
#  'Intelligenesis',
#  'Werner Enterprises',
#  'University of Houston',
#  'KKR & Co',
#  'TRUST PAC',
#  'Bonanza Oil',
#  'G&C Autobody',
#  'Nelson, Mullins et al',
#  'HK Research',
#  'Kainos Capital',
#  'National Pork Producers Council',
#  'Crystal Run Healthcare',
#  'North Carolina Leadership Fund',
#  'Pilot Corp',
#  'Energy Future Holdings Corp',
#  'Heller Realty',
#  'M&R Management',
#  "Continuing America's Strength & Security",
#  'Mosaic Media Group',
#  'Leg Avenue Inc',
#  'Time Warner',
#  'Qualcomm Inc',
#  'Advocare International',
#  'Michels Corp',
#  'Telapex Inc',
#  'Dell Technologies',
#  'Pop Fishing & Marine',
#  'Mentor Network',
#  'Parkway Development',
#  'Teramana Enterprises',
#  'Hanning & Bean Enterprises',
#  'Rockwell Collins Inc',
#  'Bollinger Shipyards',
#  'National Amusements Inc',
#  'Mana Products',
#  'Altos Eye Physicians',
#  'Exxon Mobil',
#  'Estrada Hinojosa & Co',
#  'LCF Enterprises',
#  'Lions Gate Entertainment',
#  'Amscot Financial',
#  'Carl Weinberg & Co',
#  'Greater New York Hospital Assn',
#  'Jayco Inc',
#  'Reclaim America PAC',
#  'Jenner & Block',
#  'Renaissance Technologies',
#  'National Assn of Prof Insurance Agents',
#  'Nextera Energy',
#  'Oshkosh Corp',
#  'Wayne Densch Inc',
#  'University of California',
#  'Timken Co',
#  'Asuragen',
#  'Agua Caliente Band of Cahuilla Indians',
#  'CB Nanda & Assoc',
#  'AES Corp',
#  'Mackenzie Capital Management',
#  'Directors Guild of America',
#  'Ironworkers Union',
#  'L Brands',
#  'Conference America',
#  'Fedex Corp',
#  'Digital Globe',
#  'Allergan PLC',
#  'Gilead Sciences',
#  'Yancey Brothers',
#  'Maryland Assn for Concerned Citizens',
#  'Hoosier Racing Tire',
#  'Mack Energy',
#  'Peirson & Patterson',
#  'Otis Eastern',
#  'Duke Energy',
#  'American Land Title Assn',
#  'Signal Hill Petroleum',
#  'Clos De La Tech',
#  'American Speech-Language-Hearing Assn',
#  'Nightingale Home Healthcare',
#  'John Roberts Toyota',
#  'Emergency Medicine Physicians Inc',
#  'Chesapeake Energy',
#  'Dermatology Assoc of Tyler',
#  'Highland Engineering',
#  'Talbot Insurance & Financial',
#  'Beasley Broadcast Group',
#  'New Breed Logistics',
#  'L&R Structural',
#  'Nelson Irrigation',
#  'Tennessee Industrial Electronics',
#  'Telephone & Data Systems Inc',
#  'Breakthru Beverage Group',
#  'Snell & Wilmer',
#  'Red Wing Publishing',
#  'Tensor Engineering',
#  'Council for a Livable World',
#  'Columbia Vista Corp',
#  'Coastal Construction Group',
#  'Cardinal Health',
#  'National Independent Automobile Dealers',
#  'National Assn of Convenience Stores',
#  'Roche Constructors',
#  'Cohen Group',
#  'Alston & Bird',
#  'Almost Family Inc',
#  'Pfizer Inc',
#  'AmerisourceBergen Corp',
#  'Wine Institute',
#  'National Apartment Assn',
#  'National Marine Manufacturers Assn',
#  'Skadden, Arps et al',
#  'Pain Management Clinic',
#  "McDonald's Corp",
#  'Dr Pepper Snapple Group',
#  'Heritage Food Service Equipment',
#  'North Shore Hematology Oncology Associates',
#  'Marlin Management Co',
#  'Murray Energy',
#  'Koch Enterprises',
#  'DaVita HealthCare Partners',
#  'Foundry Group',
#  'Jaffe, Raitt et al',
#  'Recording Industry Assn of America',
#  'ActBlue',
#  'McKinney Capital',
#  'SchoolsFirst Federal Credit Union',
#  'Investment Co Institute',
#  'Anschutz Corp',
#  'Mewbourne Oil Co',
#  'Amerikohl Mining',
#  'American Institute of Architects',
#  'Sheetz Inc',
#  'Sella Dev',
#  'GCG Partners',
#  'East Tennessee Pain Medicine',
#  'FRS Capital Corp',
#  'Live Oak Bank',
#  'Power Financial Corp',
#  'Outdoor Advertising Assn of America',
#  'CM Tucker Lumber Companies',
#  'Schneider National',
#  'American Institute of CPAs',
#  'FedEx Corp',
#  'Liberman Broadcasting',
#  'Northwestern University',
#  'Milestone Electric',
#  'NVR Inc',
#  'Eisai Co Ltd',
#  'Friends of Medical Research',
#  'Oasis Petroleum',
#  'Sawdey Solution Services',
#  'Campbell Co',
#  'Bain Capital',
#  'Hubbard Broadcasting',
#  'Cox Enterprises',
#  'Avera Health Systems',
#  'Silveus Insurance Group',
#  'Friedkin Group',
#  'Irving Moskowitz Foundation',
#  'Kleinberg, Kaplan et al',
#  'American Maritime Officers',
#  'Akin, Gump et al',
#  'American Federation of Govt Employees',
#  'Blackrock Inc',
#  'Arrow United Investment',
#  'Dubois Hospital',
#  'Royal Business Bank',
#  'Affiliated Managers Group',
#  'Bolla Management',
#  'Western Rim Properties',
#  'Law Offices of Peter G Angelos',
#  'NextGen Management',
#  'Roswell Toyota',
#  'Guardian Life Insurance',
#  'Morning Fresh Farms',
#  'Amneal Pharmaceuticals',
#  'Heartland Realty Investors',
#  'Peter G Peterson Foundation',
#  'Citigroup Inc',
#  'Station Casinos',
#  'University of Michigan',
#  'Heartland Values PAC',
#  'SureID',
#  'American Fedn of St/Cnty/Munic Employees',
#  'Nimeks Organics',
#  'Ultimate Fighting Championship',
#  'Avalon Holdings',
#  'California Dairies Inc',
#  'Bass Brothers Enterprises',
#  'American Dental Assn Political Ac',
#  'American Academy of Orthopaedic Surgeons',
#  'Schwendeman Agency',
#  'Cole, Schotz et al',
#  "Cozen O'Connor",
#  'Royal Brush Manufacturing',
#  'CMI Group',
#  'Reynolds American',
#  'White Castle System',
#  'Fl Crane & Sons Construction',
#  'McCleskey Assoc',
#  'Tate Enterprises',
#  'Oil City Iron Works',
#  'Deseret International Forwarding',
#  'Calpine Corp',
#  'OC Tanner Co',
#  'Cherokee Nation',
#  'Allied Pilots Assn',
#  'McKesson Corp',
#  'Livestock Marketing Assn',
#  'Nix, Patterson & Roach',
#  'Gdc Properties',
#  'Ecs Federal',
#  'Ingram Industries',
#  'Partners HealthCare',
#  'Alex Lee Inc',
#  'Caremi Partners',
#  'iHeartMedia Inc',
#  'Lowells Pharmacy',
#  'Rpm International',
#  'Unitedhealth Group',
#  'Surgical Care Affiliates',
#  'Charmer Sunbelt Group',
#  'Bencoe & Lacour Law',
#  'Entertrainment Junction',
#  'Walt Disney Co',
#  'PricewaterhouseCoopers',
#  'Lakeview Farms',
#  'Robins, Kaplan et al',
#  'Alphabet Inc',
#  'American Society of Interventional Pain Physicians',
#  'Midwest Values PAC',
#  'HJ Kalikow & Co',
#  'Creative Artists Agency',
#  'Maxwell Group',
#  'Constellation Brands',
#  'National Assn Of Broadcasters',
#  'University of Chicago',
#  'Emergent BioSolutions',
#  'Milksource',
#  'Southeastern Freight Lines',
#  'Empire Distributors',
#  'Franklin L Haney Co',
#  'Carpenters & Joiners Union',
#  'Lifepoint Health',
#  'American Investment Council',
#  'American Academy of Family Physicians',
#  'Cerner Corp',
#  'ASCAP',
#  'Northwest Excavating',
#  'Intl Brotherhood of Electrical Workers',
#  'McT Industries',
#  'Lamar Advertising',
#  'Jones Walker LLP',
#  'Kirkland & Ellis',
#  'American Medical Assn',
#  'Waterson Terminal Services',
#  'American Physical Therapy Assn',
#  'Superior Plumbing',
#  'Gbs Group',
#  'Glidewell Laboratories',
#  'Avalon Advisors',
#  'Dex Imaging',
#  'Union Pacific Corp',
#  'Water Valley Land Co',
#  'North American Properties',
#  'Uline Inc',
#  'Democratic Party of New York',
#  'American Academy of Otolaryngology',
#  'S Abraham & Sons',
#  'Integrated Medical Professionals',
#  'Eastman Kodak',
#  'Centene Corp',
#  'Greenberg Traurig LLP',
#  'Archer Daniels Midland',
#  'Hoosiers First PAC',
#  'Charter Communications',
#  'Acadian Companies',
#  'Signature Bank',
#  'Anadarko Petroleum',
#  'Democrats Win Seats PAC',
#  'National Assn of Insurance & Financial Advisors',
#  'Mbi Energy Services',
#  'Dominion Resources',
#  'Central Management',
#  'American Pistachio Growers',
#  'National Distributing Co',
#  'Celgene Corp',
#  'Viaero Wireless',
#  'American Occupational Therapy Assn',
#  'University of Nebraska Medical Center',
#  'Braman Motorcars',
#  'Faegre Baker Daniels',
#  'Great Lakes Sugar Beet Growers Assn',
#  'United Parcel Service',
#  'Molina Healthcare',
#  'Richard & Barbara Gaby Foundation',
#  'Netflix Inc',
#  ...]

# %%
#This way did not work
leg_nodes = [node for node in G.nodes() if node in list(df['cid'])]
contrib_nodes = G.nodes() - leg_nodes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-6168d95c8378> in <module>()
#       1 leg_nodes = [node for node in G.nodes() if node in list(df['cid'])]
# ----> 2 contrib_nodes = G.nodes() - leg_nodes
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
print(len(leg_nodes),len(contrib_nodes),len(G.nodes()))
# Out:
# 537 1876 2413

# %% [markdown]
# ### Finding contributors to a specific candidate
#
# Let's look at the donors to Georgia Senator David Perdue.
#
# The legislators are nodes in the network, and are indexed by the `cid`, which is a unique identifier.

# %%
get_leg_by_name('David Perdue')['cid']
# Out:
# 213    N00035516
# Name: cid, dtype: object

# %% [markdown]
# We can find the neighbors using `nx.neighbors`

# %%
nx.neighbors(G,'N00035516')
# Out:
# ['AFLAC Inc',
#  'KPMG LLP',
#  'Home Depot',
#  "Wendy's Co",
#  'Club for Growth',
#  'Cox Enterprises',
#  'Koch Industries',
#  'Delta Air Lines',
#  'Southern Co',
#  'Southeastern Minerals']

# %%
print([_ for _ in nx.neighbors(G,'N00035516')])
# Out:
# ['AFLAC Inc', 'KPMG LLP', 'Home Depot', "Wendy's Co", 'Club for Growth', 'Cox Enterprises', 'Koch Industries', 'Delta Air Lines', 'Southern Co', 'Southeastern Minerals']

# %% [markdown]
# Unfortunately, Pandas makes the `cid` a weird structured object, so we have to call `.values[0]` to get the actual string. Let's just write another function.

# %%
leg_attr = lambda leg, attr : leg[attr].values[0]

# might break if two legislators have the same name
name_to_cid = lambda name : leg_attr(get_leg_by_name(name),'cid')

cid_to_name = lambda cid : leg_attr(get_leg_by_cid(cid),'firstlast')

# %%
print(name_to_cid('David Perdue'))
print(cid_to_name(name_to_cid('David Perdue')))
print([_ for _ in nx.neighbors(G,name_to_cid("David Perdue"))])
# Out:
# N00035516
# David Perdue
# ["Wendy's Co", 'Koch Industries', 'Club for Growth', 'Cox Enterprises', 'Southeastern Minerals', 'Delta Air Lines', 'KPMG LLP', 'AFLAC Inc', 'Southern Co', 'Home Depot']

# %%
get_donors = lambda name : nx.neighbors(G,name_to_cid(name))

# %%
get_leg_by_name('John Lewis')
# Out:
#     bioguide_id   birthdate        cid comments  \
# 203     L000287  1940-02-21  N00002577      NaN
#
#                       congress_office  exit_code   facebook_id           fax  \
# 203  343 Cannon House Office Building          0  RepJohnLewis  202-225-0351
#
#      feccandid  first_elected                ...                gender  \
# 203  H6GA05217           1986                ...                     M
#
#     lastname office party         phone    twitter_id votesmart_id  \
# 203    LEWIS   GA05     D  202-225-3801  RepJohnLewis      26820.0
#
#                                                webform  \
# 203  https://johnlewis.house.gov/contact-me/email-m...
#
#                          website                       youtube_url
# 203  https://johnlewis.house.gov  https://youtube.com/repjohnlewis
#
# [1 rows x 21 columns]

# %%
get_donors('John Lewis')
# Out:
# ['American Federation of Teachers',
#  'Home Depot',
#  'Credit Union National Assn',
#  'DaVita HealthCare Partners',
#  'Cox Enterprises',
#  'American Fedn of St/Cnty/Munic Employees',
#  'Coca-Cola Co',
#  'Saban Capital Group',
#  'American Academy of Ophthalmology',
#  'CSX Corp']

# %% [markdown]
# Let's see who else got donations from Delta Air Lines

# %%
print([_ for _ in nx.neighbors(G,'Delta Air Lines')])
print([cid_to_name(cid) for cid in nx.neighbors(G,'Delta Air Lines')])
# Out:
# ['N00030980', 'N00002593', 'N00035516', 'N00032243', 'N00029391', 'N00007781', 'N00028958', 'N00031412', 'N00027500']
# ['Kelly Ayotte', 'Johnny Isakson', 'David Perdue', 'Jody B Hice', 'Erik Paulsen', 'Peter DeFazio', 'Jason Chaffetz', 'Mick Mulvaney', 'Amy Klobuchar']

# %% [markdown]
# Let's see what political party each of these legislators is from.

# %%
print([leg_attr(get_leg_by_cid(cid),
                'party')
       for cid in nx.neighbors(G,'Delta Air Lines')])
# Out:
# ['R', 'R', 'R', 'R', 'R', 'D', 'R', 'R', 'D']

# %% [markdown]
# **Your turn**: Find out what state each of these legislators is from.
#
# To do this, use the `office` attribute. The first two characters of the `office` indicate the state. If the second two characters are digits, then they indicate a district in the house of representatives; if second two characters are 'S1' or 'S2' then the legislator is a senator.

# %%
# your code here
print([leg_attr(get_leg_by_cid(cid),
                'office')
       for cid in nx.neighbors(G,'Delta Air Lines')])
# Out:
# ['NHS1', 'GAS2', 'GAS1', 'GA10', 'MN03', 'OR04', 'UT03', 'SC05', 'MNS2']

# %% [markdown]
# ## Degree distributions
#
# The degree of a node is the number of neighbors that the node has in the graph.
#
# By construction, we can see only the top 10 contributors to each legislator. So their degree should always be 10. But for the contributors, there should be more diversity.
#
# You can compute the degree for any node by calling `nx.degree(G,node)`

# %%
nx.degree(G,'Facebook Inc')
# Out:
# 5

# %% [markdown]
# Which contributor donates to the most legislators?

# %%
# dictionary of contributors and their degrees
degrees = {contrib:nx.degree(G,contrib) for contrib in contrib_nodes}

# useful code for getting the key in a dict with the maximum value
max(degrees,key=degrees.get)
# Out:
# 'Blue Cross/Blue Shield'

# %%
nx.degree(G,'Blue Cross/Blue Shield')
# Out:
# 90

# %% [markdown]
# Let's plot a degree distribution

# %%
#the x-axis on the left is just an index indicating the number of degree values. 
#this shows the degree distribution follows a power law: some donors give to a lot, 
#many give to few. This might describe the process by which campaign contributions are made
#if fewer donors have larger budgets for campaign contributions, 
#or only fewer donors seek influence across state lines, across senate and house levels,
#or across party lines.
fig,ax=plt.subplots(1,2,figsize=[11,3])
ax[0].plot(sorted(degrees.values(),reverse=True))
ax[0].set_ylabel('degree')
ax[1].loglog(sorted(degrees.values(),reverse=True))
ax[1].set_ylabel('log degree');

# %% [markdown]
# The log-log plot is nearly linear, after the top 10 or 12 contributors. This means that this part of the distribution is approximated by a **power law**. We have observed a similar distribution over the frequencies of words. When a network's degree distribution follows a power law, the network is said to be [scale-free](https://en.wikipedia.org/wiki/Scale-free_network).
#
# Scale-free networks can arise from a generative process featuring [preferential attachment](https://en.wikipedia.org/wiki/Barab%C3%A1si%E2%80%93Albert_model): as new nodes are added to the graph, their likelihood of linking to some existing node is proportional to the degree of that node.
#
# **Discuss**: Do you think preferential attachment (PA) describes the process by which campaign contributions are made to legislators? What are some possible mechanisms that are consistent with PA? Why might contributors *not* behave according to PA?

# %% [markdown]
# ## Betweenness
#
# As described at the end of chapter 3 of the reading from [Networks Crowds and Markets](https://www.cs.cornell.edu/home/kleinber/networks-book/networks-book-ch03.pdf), the quantity of **betweenness** measures the extent to which a given edge can partition the graph. Betweenness centrality is the fraction of shortest paths on which each node sits.

# %%
# this dictionary takes a little while to create
#either of these returns the same thing
#btw_centrality = nx.bipartite.centrality.betweenness_centrality(G,contrib_nodes)
btw_centrality = nx.bipartite.centrality.betweenness_centrality(G,leg_nodes)

# %%
btw_centrality
# Out:
# {'Biloxi Freezing & Processing': 0.0,
#  'Fannie Mae': 0.0,
#  'Emergency Medicine Consultants': 0.0,
#  'Lozier Corp': 0.0,
#  'McMl PA': 0.0,
#  'Bridge Capital': 0.0,
#  'Saltchuk Resources': 9.484277753091304e-05,
#  'Express Scripts': 0.0019384748933423783,
#  'Transport Workers Union': 0.0004994579823429299,
#  'N00004558': 0.006717543725612009,
#  'Welsh, Carson et al': 8.707745430131386e-05,
#  'N00026710': 0.003383057201249593,
#  'Gershow Recycling': 0.0,
#  'United Transportation Union': 3.307071853261174e-05,
#  'WPP Group': 0.002462103000094705,
#  'Fragomen, Del Rey et al': 3.0918553739604155e-05,
#  'Ozarks Coca-Cola': 0.0,
#  'N00025495': 0.005775226062320963,
#  'Cajun Industries': 0.00018962838510232889,
#  'American Council of Engineering Cos': 0.009339612232715207,
#  'Boilermakers Union': 0.0008069922237071305,
#  'Teamsters Union': 0.0002838797362697216,
#  'New Balance Athletic Shoe': 0.0,
#  'N00035403': 0.005570282355037172,
#  'American Federation of Teachers': 0.023247456907227532,
#  'N00001746': 0.0034330260737456208,
#  'N00030829': 0.005595940394039658,
#  'Forhan Co': 0.0,
#  'Majestic Realty': 0.0,
#  'Berry Investments': 0.0,
#  'Zions Bancorp': 0.00018773770127131993,
#  'Hagan, Noll & Boyle': 0.0,
#  'N00001758': 0.004204392729802254,
#  'Archer & Greiner': 0.0,
#  'N00030880': 0.003105878052316729,
#  'Batavia Enterprises': 0.0,
#  "Richie's Specialty Pharmacy": 0.0,
#  'Deere & Co': 0.0008865126985714967,
#  'N00029016': 0.003462340837769633,
#  'Conklin Co': 2.0787812438913e-05,
#  'N00006249': 0.0032970192955698815,
#  'General Dynamics': 0.0079690404194859,
#  'N00035774': 0.004409148396524537,
#  'Pisces Inc': 2.8601257090462552e-05,
#  'N00031103': 0.004130038951757826,
#  'N00033842': 0.0038657986879192473,
#  'Crowe Horwath LLP': 0.0,
#  'Astrophysics Inc': 0.0,
#  'N00031128': 0.0014312732256646242,
#  'Hensel Phelps Construction': 0.0,
#  'Freedom Project': 0.00014325126069145345,
#  'N00009724': 0.002995164538639025,
#  'N00007017': 0.0036961136249460845,
#  'N00029070': 0.0027014206160513535,
#  'American Peanut Shellers Assn': 0.0,
#  'American Bankers Assn': 0.053097185192039736,
#  'Soros Fund Management': 0.0,
#  'Innovative Defense Technologies': 0.0,
#  'N00000898': 0.003834885201197327,
#  'N00033539': 0.004267897949688343,
#  'N00024753': 0.005061346992208936,
#  'N00003209': 0.003659543696113865,
#  'N00030608': 0.004662412427059469,
#  'N00000939': 0.00401506472801759,
#  'American Subcontractors Assn': 0.0,
#  'N00025284': 0.0014479544627738125,
#  'Alro Steel': 0.0,
#  'N00031559': 0.004887981900009786,
#  'Pacers Sports & Entertainment': 0.0,
#  'Agio International': 0.0,
#  'Charah Inc': 0.0,
#  'Boston Scientific Corp': 0.0,
#  'Caesars Entertainment': 0.00022953736671900833,
#  'Senior Star Living': 3.6990622216427114e-05,
#  'Jazz Pharmaceuticals': 0.0,
#  'Bremen Castings': 0.0,
#  'McDowell Enterprises': 0.0,
#  'Keyes Automotive Group': 2.6397189557916643e-05,
#  'Alexander & Baldwin': 0.0005243491535980035,
#  'Topspin Partners': 0.0,
#  'Democrats Time In Nevada': 0.0,
#  'Knight Transportation': 6.935292034939847e-05,
#  'Granville Homes': 0.0004545249585606034,
#  'UnitedHealth Group': 0.0001071483321337763,
#  'New Breed Inc': 0.0,
#  'Stevens & Lee': 0.0,
#  'Crow Holdings': 3.2246455309387357e-05,
#  'N00004724': 0.0033963678489635214,
#  'American Pharmacists Assn': 0.0,
#  'Switch Supernap': 0.0,
#  'Adams Robinson Enterprises': 0.0,
#  'Impact Plastics': 0.0,
#  'Ernst & Young': 0.0317096844335509,
#  'Council of Insurance Agents & Brokers': 0.005951241738788775,
#  'Anderson Trucking Services': 0.0,
#  'N00030856': 0.002425099493721585,
#  'Alkermes Plc': 4.562884249555905e-05,
#  'Blue Cross/Blue Shield': 0.1363521528414115,
#  'Alston, Hunt et al': 0.0,
#  'Simmons First National': 0.0,
#  'Terra Linda Farms': 0.0,
#  'Marcus & Millichap': 0.001377294544484705,
#  'Harbert Management': 0.0,
#  'Texas A&M University': 0.0,
#  'N00030197': 0.003478759072137527,
#  'N00029632': 0.004530488495300216,
#  'Prestage Farms': 0.0,
#  'Operating Engineers Union': 0.0017151142067586488,
#  "St George's University": 0.0004563792602100554,
#  'N00024992': 0.006800800104298239,
#  'Harris Corp': 0.0016891012247185887,
#  'Kleiner, Perkins et al': 1.3700164662104978e-05,
#  'Visa Inc': 0.0,
#  'Desert Caucus': 0.001333614582458121,
#  'Fanjul Corp': 0.0011771627203125642,
#  'Primerica Inc': 0.0,
#  'US Senate': 0.0,
#  'Forsyth Plastic Surgery': 0.0,
#  'US Bancorp': 0.0012656931798091934,
#  'Bancorpsouth': 0.0,
#  'Wolverine Gas & Oil': 0.0,
#  'Wall-Snow Realty': 0.0,
#  'GMS Mine Repair & Maintenance': 0.0,
#  'Mansour Co': 0.0,
#  'Corporate Capital LLC': 0.0,
#  'N00008028': 0.004105520909160875,
#  'Nibco Inc': 0.0,
#  'Capital Group': 1.8489157520627034e-05,
#  'National Assn of Home Builders': 0.002301876276559023,
#  'N00009573': 0.00249757678725467,
#  'NCTA The Internet & Television Assn': 0.00012153481100829801,
#  'American College of Surgeons': 0.000760372949421631,
#  'National Alliance of Forest Owners': 0.0,
#  'United Contractors Midwest': 0.0,
#  'N00006023': 0.00243730128502135,
#  'Plainscapital Corp': 0.0,
#  'First Bank': 0.0,
#  'Blessey Marine Service': 8.530093375182743e-05,
#  "National Cattlemen's Beef Assn": 0.0054039060143422435,
#  'N00036107': 0.0024059903392196417,
#  'Facebook Inc': 0.0009958609315666989,
#  'All American Asphalt': 0.0,
#  'College Loan Corp': 0.0006040727493404422,
#  'N00012672': 0.00741452910602553,
#  'Leonardo-Finmeccanica': 0.0,
#  'Re/Max International': 0.0,
#  'Cerberus Capital Management': 0.0002773249741561266,
#  'Mantech International': 1.9749795947321504e-05,
#  'N00033395': 0.002583275129588119,
#  'Apollo Global Management': 0.0016471344550048105,
#  'Drinker, Biddle & Reath': 0.0,
#  'N00009660': 0.005244739038928862,
#  'Capital Corp': 0.0,
#  'N00035934': 0.004836895789904794,
#  'N00030736': 0.0023776580364418256,
#  'National Electrical Contractors Assn': 0.0,
#  'Georgetown University': 0.0008108674498182543,
#  'Frontera Resources': 0.0,
#  'Rock Management Group Ltd': 0.0,
#  'Act for Entertainment': 0.0,
#  'N00000615': 0.0035607758149944005,
#  'N00030693': 0.004634866765190648,
#  'Park Ohio Holdings': 0.0,
#  'Kaitar Resources': 0.0,
#  'Cronley Construction Co': 0.0,
#  'Hess Corp': 0.00016160244957923273,
#  'American Financial Group': 0.00105544926404411,
#  'Rain & Hail Insurance Society': 0.0,
#  'Silver Lake Partners': 0.0,
#  'N00033443': 0.004914281808359157,
#  'Nutramax Laboratories': 0.0004362850195452239,
#  'N00030071': 0.004361624618229916,
#  'Texas Star Investments': 0.0,
#  'GST Inc': 0.0,
#  'American Assn of Crop Insurers': 6.765689261417282e-05,
#  'American Trucking Assns': 4.0088728606055805e-05,
#  'Western Mutual Insurance': 0.0,
#  'Kojaian Companies': 4.8078938796034695e-05,
#  'Medico Industries': 0.0,
#  'N00006671': 0.0017570673836438846,
#  'Portland General Electric': 0.0,
#  'University of Washington': 3.214749268671788e-05,
#  'Genesis 10': 0.0,
#  'Brown Rudnick Llp': 0.0,
#  'American Society of Travel Agents': 0.0,
#  'First Premier Bank': 0.0,
#  'Eli Lilly & Co': 0.002222002981854715,
#  'AFLAC Inc': 0.004664420346483426,
#  'N00028463': 0.00741452910602553,
#  'N00030980': 0.00212799320361108,
#  'N00006446': 0.003278946536263565,
#  'Genworth Financial': 0.0,
#  'Citadel LLC': 0.0002486449820938024,
#  'National Ready Mixed Concrete Assn': 0.0,
#  'Woodward Inc': 0.0,
#  'AECOM Global': 6.96891051843062e-05,
#  'National Rural Electric Cooperative Assn': 0.0027322143444552913,
#  'Paul, Weiss et al': 0.0002713529705488746,
#  'Pinnacle West Capital': 0.0019467692141789516,
#  'Oriental Financial Group': 0.0,
#  'N00013873': 0.0035021909595009284,
#  'N00034224': 0.0028875175482080385,
#  'Continental Properties': 0.0,
#  'Good Stuff Fishing LLC': 0.0,
#  'Silvercrest Asset Management': 0.0,
#  'Kenan Advantage Group': 0.0,
#  'Carlyle Group': 0.00153408801280996,
#  'Sv Angel LLC': 0.0,
#  'ACA International': 0.0,
#  'Novogradac & Co': 0.0,
#  'BNP Paribas': 0.00037169527700828617,
#  'Pivotal Group': 0.0,
#  'Western National Group': 0.0,
#  'Service Employees International Union': 0.0006387967390464893,
#  'Sanford Health': 0.0,
#  'N00012508': 0.005345766040534428,
#  'Arizona Diamondbacks/Datatel Inc': 0.0,
#  'Tenax Aerospace': 0.0,
#  'N00028133': 0.0037036890158233526,
#  'Regeneron Pharmaceuticals': 0.0,
#  'N00030645': 0.004086937058994964,
#  'Clear': 0.0,
#  'Northrop Grumman': 0.014779233708503045,
#  'Society of Interventional Radiology': 0.0,
#  'N00030602': 0.004290291261757078,
#  'Independent Community Bankers of America': 2.4444964561827954e-05,
#  'McWane Inc': 2.5091256549680006e-05,
#  'N00003280': 0.004009026271162548,
#  'N00026926': 0.0028865094183495713,
#  'Central Pacific Financial': 0.0,
#  'WPX Energy': 0.0,
#  'Silver Eagle Distributors': 0.0003259191367964018,
#  'N00033549': 0.003807442077478578,
#  'Murphy Endeavors': 0.0,
#  'Islands Mechanical': 0.0,
#  'DANPAC': 0.0,
#  'Connolly Coastal Capital': 0.0,
#  'N00034277': 0.003924041715680145,
#  'N00004118': 0.0043447431859982965,
#  'N00024922': 0.0040550125991438086,
#  'Blue Diamond Growers': 1.225467737039429e-05,
#  'Brown Brothers Harriman & Co': 6.930337492909847e-05,
#  'B&G Food Enterprises': 0.0,
#  'TeleCommunication Systems Inc': 0.0,
#  'Impact': 0.0,
#  'Peninsula PAC': 0.0,
#  'John Bolton PAC': 0.0003220808861703265,
#  'Moveon.org': 0.00020972567566282358,
#  'N00033640': 0.005108838019311062,
#  'N00024870': 0.004229673078159646,
#  'Schahet Hotels': 0.0,
#  'Integral Manufacturing': 0.0,
#  'Kobayashi, Sugita & Goda': 0.00010051019221275808,
#  'Avenue Ventures': 0.0,
#  'Casaca Vineyards': 0.0,
#  'Icee Distributors': 0.0,
#  'Farm Credit Council': 0.0041971596221730915,
#  'Paul Rogers & Assoc': 0.0,
#  'Xana Management': 0.0,
#  'Baupost Group': 0.0,
#  'Dykema Gossett': 0.0,
#  'N00031227': 0.002367727852127584,
#  'BASF SE': 8.938418052728902e-05,
#  'DuPont Co': 5.499527698129455e-05,
#  'Holtec International': 0.0,
#  'Scentsy': 0.0,
#  'Womencount PAC': 1.5082884608268934e-05,
#  'American Society of Anesthesiologists': 0.006358301663458987,
#  'SEAKR Engineering': 0.0,
#  'Chicago Bridge & Iron': 0.0,
#  'Harbor Freight Tools': 0.0002583772075405801,
#  'Verizon Communications': 0.001044074639837908,
#  'Ibm': 0.0,
#  'American Crystal Sugar': 0.062481137427688266,
#  'Musical Instruments Museum': 0.0,
#  'AVT Ventures': 0.0,
#  'Mednax Inc': 3.215441378968857e-05,
#  'United Food & Commercial Workers Union': 0.0005747521802367939,
#  'Peabody Energy': 0.0,
#  'Campbell Companies': 0.0,
#  'Target Corp': 2.8362843943564366e-05,
#  'Willis Group Holdings': 0.0,
#  'N00030670': 0.004879821081793622,
#  'National Community Pharmacists Assn': 0.00010285958450442826,
#  'N00004874': 0.0028738504065654903,
#  'N00025237': 0.006945203857704476,
#  'Ted Poe for Congress': 0.0,
#  'Koskoff, Koskoff & Bieder': 0.00022654476480263574,
#  'McWilliams Government Affairs': 0.0,
#  'N00030768': 0.005270231648230845,
#  'Huntington Ingalls Industries': 0.0029560618617267887,
#  'N00000575': 0.001935523303942424,
#  'Liberty Media': 0.0,
#  'Chickasaw Nation': 0.0,
#  'GOJO Industries': 0.0,
#  'Devon Energy': 0.00047225474282813393,
#  'Duane Morris LLP': 0.0,
#  'N00033982': 0.004000487538647512,
#  'Boeing Co': 0.06459119190764867,
#  'Everglades College': 5.668073119370505e-05,
#  'Rely on Your Beliefs': 0.0007300285850986144,
#  'Link Group': 7.663593994963053e-05,
#  'Johns Hopkins University': 0.0014328478459719816,
#  'Nucor Corp': 0.0,
#  'Humane Society of the US': 0.0,
#  'Varischetti & Sons': 0.0,
#  'N00006263': 0.0035304504704558592,
#  'American Lighting Assn': 0.0001096460386166232,
#  'General Communication Inc': 0.0,
#  'Phipps Anderson Deacon Llp': 0.0,
#  'RJ Corman Railroad Group': 0.0,
#  'N00026335': 0.007302992755173006,
#  'Xcel Energy': 0.0,
#  'Mtsu': 0.0,
#  'N00037031': 0.005001245417588057,
#  'Knight Hawk Coal': 0.0,
#  'HECK YES! VICTORY FUND': 0.0,
#  'Peachtree Orthopaedic Clinic': 0.0,
#  'Goldsboro Milling': 0.0,
#  'House Liberty Fund': 0.0,
#  'Smart Pharmacy': 0.0002901849693049531,
#  'Circle Packaging Machinery': 0.0,
#  'Ruan Companies': 0.0,
#  'Gideon, Cooper & Essary': 0.0,
#  'Credit Suisse Group': 0.0002017431269520571,
#  'TPG Capital': 0.0,
#  'Miller & Martin': 0.0,
#  'Sandlapper Securities': 0.0,
#  'Federated Investors Inc': 0.005583341448302975,
#  'N00031265': 0.003081215257014454,
#  'N00003225': 0.0037936471332882136,
#  'COLE PAC': 0.0,
#  'N00006897': 0.005609949024864917,
#  'Oberlin College': 0.0,
#  'Principal Financial Group': 0.0,
#  'Cdi': 0.0,
#  'Indiana University': 0.0,
#  'N00033518': 0.0037912438678487513,
#  'Worldwide Language Resources': 0.0,
#  'Ozark Mountain Poultry': 0.0,
#  'N00007876': 0.005688166772775465,
#  'Federation of American Hospitals': 0.0,
#  'Susman Godfrey LLP': 0.0,
#  'Salopek 6u Farms': 0.0,
#  'Votesane PAC': 0.03940019365163825,
#  'Scranton Label Inc': 0.0,
#  'N00000267': 0.0037656372064017855,
#  'Banc First': 0.0,
#  'PCC/Customs Brokers & Freight Forwarders': 0.0,
#  'Microsoft Corp': 0.010430032819749654,
#  'Monsanto Co': 4.30263062284794e-05,
#  'Aloha Partners': 0.0,
#  'General Electric': 0.008451634573447228,
#  'Calvi Electric': 0.0,
#  'N00026631': 0.003804175017434079,
#  'N00001945': 0.003899754826951712,
#  'Marriott International': 9.287735193009767e-05,
#  'Jenzabar Inc': 0.0,
#  'Betz Industries': 0.0,
#  'Harvard University': 0.0018333830284205394,
#  'Costas Provisions': 0.0,
#  'N00004291': 0.00581395366208139,
#  'Exelon Corp': 0.008584218270153578,
#  'Amway/Alticor Inc': 0.009200129263893983,
#  'Fairfax County, VA': 0.0,
#  'Marshfield Clinic': 0.0,
#  'Keller Investment Properties': 3.0135286709215345e-05,
#  'Boston University': 0.0,
#  'Virginia Urology': 0.0,
#  'Magnus Pacific': 0.0,
#  'Dannenbaum Engineering': 0.0019824194339967145,
#  'Allen Morris Co': 0.0,
#  'National Multi Housing Council': 0.00026869997219157037,
#  'N00033085': 0.00502241946611151,
#  'Aitken, Aitken & Cohn': 0.0,
#  'Financial Service Centers of America': 0.0,
#  'Calvary Hospital': 0.0,
#  'Lockheed Martin': 0.02114307847883853,
#  'N00031688': 0.0036289219879493038,
#  'Covelli Enterprises': 0.0,
#  'Computer Sciences Corp': 0.0,
#  'Atco Investment': 0.0,
#  'Regional Urology': 0.0,
#  'N00031958': 0.004661628195126371,
#  'Maurer & Scott Sales': 0.0,
#  'Marsh & McLennan': 0.0,
#  'Nuclear Energy Institute': 0.0,
#  'SF Investments': 0.0,
#  'N00027566': 0.0033512277687079667,
#  'N00031593': 0.0044931259600686155,
#  'News Corp': 0.0,
#  'Research Affiliates LLC': 4.3631503808504975e-05,
#  'N00031877': 0.0026245407019337237,
#  'Jennmar Corp': 0.0005004931751052172,
#  'Mylan Inc': 0.0,
#  'Mockler Beverage': 0.0,
#  'Cancer Treatment Centers of America': 0.0002559219387057812,
#  'Friends Of David Schweikert': 0.0,
#  'Alliance Resource Partners': 0.00046023287843194755,
#  'Intellectual Ventures LLC': 0.0006403387479919124,
#  'N00035691': 0.006105195048187612,
#  'Russell Stover Candies': 7.929216649366335e-05,
#  'National Assn of Truck Stop Operators': 0.0,
#  'Cook Group': 0.0,
#  'Hartford Financial Services': 3.1596581265513004e-05,
#  'National Auto Dealers Assn': 0.005274954921059427,
#  'American Assn for Justice': 0.007007102241102817,
#  'Prudential Financial': 0.002619366853834893,
#  'Ag Services': 0.0,
#  'Cablevision Systems': 0.0,
#  'Comerica Inc': 3.2246455309387357e-05,
#  'N00026586': 0.003427127303738135,
#  'Southwestern Co': 0.0,
#  'Ocean Shipholdings': 0.0,
#  'Alliant Techsystems': 0.0,
#  'N00031377': 0.0041885883164261934,
#  'Brady for Congress': 0.0,
#  'N00007360': 0.003558733635195411,
#  'N00034416': 0.004342154134606147,
#  'Dow Chemical/Corning': 0.0,
#  'N00030752': 0.004763908355165686,
#  'Foundation Medicine': 0.0,
#  'N00009816': 0.005285110890262919,
#  "Bracey's Supermarkets": 0.0,
#  'Trident Seafoods': 0.0,
#  'ConocoPhillips': 0.00021646260949714292,
#  'N00036403': 0.005223501608130791,
#  'N00034254': 0.004718587980524987,
#  'Preston Development': 0.0,
#  'Precision Paper & Board': 0.0,
#  'Ultra Electronics': 0.0,
#  'Advanced Integrated Technologies LLC': 0.0,
#  'LDI Ltd': 0.0,
#  'Kennedy-sinema Victory Fund': 0.0,
#  'Masimo Corp': 0.0,
#  '3M Co': 0.0,
#  'Barnes & Thornburg': 0.0008415730262328081,
#  'Bradley, Arant et al': 0.0,
#  'Crawford Group': 0.002219727564574703,
#  'Newport Orthopedic Institute': 0.0,
#  '1st Family Dental': 0.0,
#  'N00031777': 0.006221981524148481,
#  'N00009918': 0.0045040314229236374,
#  'N00028257': 0.0037658941246335735,
#  'KPMG LLP': 0.000715796092434983,
#  'Bb&T Corp': 0.0,
#  'Agree Realty': 0.0,
#  'Prime Inc': 0.0,
#  'Element Electronics': 0.0,
#  'Air Products & Chemicals Inc': 2.932250609449612e-05,
#  'Lathrop & Gage': 0.0,
#  'Shaheen & Gordon': 0.0,
#  'N00031317': 0.005812694350812879,
#  'Pioneer Nursery': 0.0,
#  'Keating, Muething & Klekamp': 0.0,
#  'Transtelco': 0.0,
#  'Hantz Group': 0.0,
#  'Simpson, Thacher & Bartlett': 0.0,
#  'World Wide Technologies': 0.0,
#  'Stronghold Engineering': 0.0,
#  'Imaging Assoc of N Ms': 0.0,
#  'Simmons Hanly Conroy': 0.00022031886795431102,
#  'Early, Lucarelli et al': 0.0,
#  'N00030196': 0.00349929694492551,
#  'Acadia Healthcare': 4.081632780016605e-05,
#  'N00025337': 0.004604019630564013,
#  'San Manuel Band of Mission Indians': 0.0,
#  'Home Depot': 0.00766898237173406,
#  'Oaktree Capital Management': 0.00020171947206565338,
#  'Pelco Structural': 3.159097349226862e-05,
#  'N00035688': 0.005366717288673361,
#  'Matson Inc': 0.0,
#  'Cisco Systems': 1.3700164662104978e-05,
#  'N00029835': 0.003951017707462602,
#  'Textron Inc': 0.0,
#  'N00025292': 0.0027874542086198727,
#  'Carroll Companies': 0.0,
#  'N00008122': 0.0033586466399111287,
#  'Broadway National Bank': 9.863065635805178e-05,
#  'Voices for Progress': 4.539308906663414e-05,
#  'Hart Group': 0.0,
#  'AEGON NV': 0.0001367774171344081,
#  'Thornton Law Firm': 0.00048598536931317344,
#  'N00007836': 0.0037755930446872086,
#  'N00002593': 0.00220649613398394,
#  'Bowdoin College': 0.0,
#  'N00007479': 0.004026346405201146,
#  'N00003675': 0.0034036995215276367,
#  'Ashland Inc': 0.0,
#  'BP': 0.00022480280376402395,
#  'N00033510': 0.0050852466136875754,
#  'N00033839': 0.005139325869351504,
#  "EMILY's List": 0.009315141614134778,
#  'N00033540': 0.006066966612923073,
#  'Red Apple Group': 0.0,
#  'Edison Chouest Offshore': 0.0021409663513090767,
#  'CMS Energy': 0.00037594961194959363,
#  'Langlas & Assoc': 0.0,
#  'N00002674': 0.0030656589377421415,
#  'Crosby Tugs': 0.0,
#  'Woodbranch Investments': 0.00827262614766494,
#  'N00005818': 0.0026795343833091742,
#  'N00008046': 0.004940569817349253,
#  'Windstream Communications': 0.0,
#  'Coughlin Construction': 0.0,
#  'Forest City Enterprises': 0.0009965401568430463,
#  'Ewing Constructions Co': 0.0,
#  'BB&T Corp': 0.0,
#  'Enervest Ltd': 0.0,
#  'Akerman LLP': 0.00011318797233717167,
#  'Committee for Hispanic Causes-BOLD PAC': 2.9949981164035317e-05,
#  'Cooks Pest Control': 0.0,
#  'Kiewit Corp': 0.0,
#  'Collier Investments': 0.0,
#  'Codina Group': 0.0,
#  'Rudin Management': 0.0,
#  'N00026686': 0.003073252054205286,
#  'N00001373': 0.0028792958331399616,
#  'Briggs & Stratton': 0.0,
#  'Chartwell Hotels': 0.0,
#  'Cronin, Fried et al': 0.0,
#  'National HealthCare Corp': 0.0,
#  'International Paper': 8.116024188076808e-05,
#  'National Stone, Sand & Gravel Assn': 0.000344087929520545,
#  'N00036175': 0.0031552747248647915,
#  'Intl Alliance Theatrical Stage Employees': 0.0,
#  'N00031933': 0.00491363709903561,
#  'Fisher Investments': 0.0,
#  'Rubin & Rudman': 0.0,
#  'N00035544': 0.006911639102568159,
#  'Belmark Inc': 0.0,
#  'Harbour Group Industries': 0.00023792643968164278,
#  'Zurich Financial Services': 0.0,
#  'N00027229': 0.00434328176229113,
#  'N00036449': 0.0065280132761100906,
#  'Eberstein & Witherite': 0.0,
#  'N00027649': 0.004233491960572067,
#  'Sugar Creek Packing': 0.0,
#  'N00032088': 0.00533507363702834,
#  'Defend America PAC': 0.0,
#  'Gci': 0.0,
#  'Home Creations': 0.0,
#  'N00033532': 0.003669804733968951,
#  'North Shore Hematology Oncology Assoc': 0.0001517882787842966,
#  'N00029662': 0.004818388431258333,
#  'Kinder Morgan Inc': 0.0,
#  'Saker ShopRites': 0.0,
#  'DeRoyal Industries': 0.0005674083084376015,
#  'N00035516': 0.003805583092183082,
#  'Consol Energy': 0.0,
#  'Willkie, Farr & Gallagher': 0.0,
#  'Cemco Inc': 0.0,
#  'Susan B Anthony List': 5.910640248160117e-05,
#  'Bank of America': 0.002800133739475213,
#  'QTC Management': 0.0,
#  'N00035535': 0.003486038090631688,
#  'N00035307': 0.0050894168747221405,
#  'American Pilots Assn': 0.0,
#  'N00027522': 0.0038609207305508866,
#  'FMC Technologies': 0.0,
#  'Gross Builders': 0.0,
#  'Nustar Energy': 0.0003148632553881179,
#  'Ward & Smith': 0.0,
#  'Fun Spot of Florida LLC': 0.0,
#  'Kirby Corp': 0.0,
#  'George Peck & Assoc, Plc': 0.0,
#  'Power, Rogers & Smith': 4.93096127744828e-05,
#  'Datron World Communications': 0.0,
#  'Seacoast Commerce Bank': 0.0,
#  'Pcca': 0.0,
#  'Law Offices of Jeremy D, Weinsttein': 0.0,
#  'Perkins Coie': 0.00011143176502094066,
#  'Applied Business Concepts': 0.0,
#  'N00030815': 0.0037547355326022903,
#  'N00000528': 0.0033383372321868885,
#  'N00003689': 0.006282170880753204,
#  'Arbor Homes': 0.0,
#  'Polsinelli PC': 0.0006897234978543816,
#  'N00001127': 0.003591722527247475,
#  'Capital Funding Group': 0.0,
#  'CGCN Group': 0.0,
#  'WilmerHale Llp': 0.00044872068724932456,
#  'McCoy Group': 0.0,
#  'For Adult Industry Responsibility Commit': 0.0,
#  'Capital One Financial': 0.0015494111223833293,
#  'N00031782': 0.007905879531722526,
#  'Bechtel Group': 0.0010679706067509057,
#  'Coalition for Student Success': 0.0,
#  'N00026368': 0.0037852015298529503,
#  'N00013846': 0.005914780169456733,
#  'N00030949': 0.00421289895371882,
#  'Omni New York': 0.0,
#  'Harrison, White et al': 2.452374214117021e-05,
#  'Alabama Farmers Federation': 2.6448744841281038e-05,
#  'Intelsat Holdings': 0.0,
#  'University of Arizona': 0.0,
#  'Pierce Atwood LLP': 0.0,
#  'Laborers Union': 0.0005573153539617562,
#  'Envirosep': 0.0,
#  'Senate Conservatives Fund': 0.004367648845731337,
#  'N00030581': 0.0024163327836200536,
#  'Akt Development': 0.0,
#  'Southern Co': 0.0041219543158200435,
#  'Amalgamated Transit Union': 0.00010761025083126045,
#  'New Hampshire Steel': 0.0,
#  'N00000743': 0.0038321173353938203,
#  'Case Western Reserve University': 0.0,
#  'Aero Metals': 0.0,
#  'N00030968': 0.006612073139904185,
#  'Powell Construction': 0.008246404859178153,
#  'American Podiatric Medical Assn': 0.004961233442038917,
#  'Right to Life': 0.0,
#  'Sutherland Capital Management': 0.00010580344359168292,
#  'TIAA': 0.0,
#  'N00029649': 0.004780234266092063,
#  'Pain Medicine Assoc': 0.0,
#  'American Seniors Housing Assn': 6.654908254582318e-05,
#  'University of New Mexico': 0.0003081179707617593,
#  'N00035792': 0.0049453000675979625,
#  'Truman Arnold Companies': 0.0,
#  'International Longshoremens Assn': 7.984371231045184e-06,
#  '4Life Research': 0.0,
#  'Island Doctors': 0.0,
#  'Gregory Rockhouse Ranch': 0.0,
#  'State of Illinois': 0.0,
#  'Cvjh LLC': 0.0,
#  'N00000491': 0.004741498779172752,
#  'Wynn Resorts': 0.00019711535975835701,
#  'Mmr Constructors': 0.0,
#  'Santo Petroleum': 0.0,
#  'SPS Studios': 0.0,
#  'Americans for the Arts': 0.0,
#  'Metlife Inc': 0.00269162554225317,
#  'Idacorp Inc': 0.0,
#  'N00006424': 0.003138243512682208,
#  'Crane & Sons': 0.0,
#  'American Development Corp': 0.0,
#  'American Hotel & Lodging Assn': 0.0,
#  'Brunswick Corp': 0.0,
#  'Kingston Technology': 0.0,
#  'N00005282': 0.004144024764421288,
#  'N00024842': 0.00346385117017688,
#  'N00027462': 0.005049811676693591,
#  'American Postal Workers Union': 0.0009288483972170765,
#  'Husch Blackwell LLP': 0.0,
#  'N00026166': 0.004664737524690545,
#  'American Kidney Stone Management': 0.00488766018120333,
#  'N00032416': 0.00227078455199162,
#  'Hy-Vee Inc': 0.0,
#  'Holland Partners': 0.0,
#  'Royal Palm Academy': 0.0,
#  'N00027510': 0.0030935640131401873,
#  'Conner, Strong & Buckelew': 0.0,
#  'Machinists/Aerospace Workers Union': 0.013787475588096145,
#  'Cooney & Conway': 4.422781590258203e-05,
#  'University of Montana': 0.0,
#  'N00035380': 0.005415077325497039,
#  'N00003328': 0.005330957743208397,
#  'Law Offices of Regina J Roger': 0.0,
#  'N00035854': 0.0058821276241311435,
#  'Barnes & Noble': 0.0,
#  'Bryan Cave LLP': 0.0007760455294472588,
#  'King Capital': 0.0,
#  'Total Military Management': 0.0,
#  'Chemorse Ltd': 0.0,
#  'Cypress Real Estate Advisors': 0.0,
#  'Air Line Pilots Assn': 0.02167737533438635,
#  'Richard Childress Racing': 0.0,
#  'N00032243': 0.0033505596706119825,
#  'Yale University': 0.00013758137078464212,
#  'Unum Group': 0.00015379343059270393,
#  'Kaiser Permanente': 0.0,
#  'Wachtell, Lipton et al': 0.0,
#  'Davidson Kempner Capital Management': 0.0,
#  'Noble Energy': 0.0,
#  'Millard Group': 0.0,
#  'Cronin Group': 0.0,
#  'Majority Cmte PAC': 0.03418761308276431,
#  "Love's Travel Stops": 0.0,
#  'Liquid Environmental Solutions': 1.591704917806938e-05,
#  'Mid Manhattan PAC': 0.0,
#  'Rock Holdings': 0.005999953032709904,
#  'United Continental Holdings': 6.73173817492612e-05,
#  'Kroger Co': 0.0,
#  'TCF Financial': 0.0,
#  'UBS AG': 0.009493118470739614,
#  'Jelly Belly Candy': 0.0,
#  'Servpro Industries': 0.0,
#  'N00009869': 0.005130215716281526,
#  'Wells Blue Bunny': 0.0,
#  'National Healthcare Corp': 0.0,
#  'Warland Investments': 0.0,
#  'N00004572': 0.008933518110199929,
#  'Jones Day': 0.00015652567294501,
#  "Katie's Seafood Market": 0.0,
#  'Suburban Collection': 9.39311546364632e-05,
#  'Vanir Development': 0.0,
#  'Norene Ranches': 1.8858688748092706e-05,
#  'N00037003': 0.003365757183020332,
#  'Astenbeck Capital Management': 0.0,
#  'James E Hall': 0.0,
#  'Kindred Healthcare': 0.00034123770653012183,
#  'Lindy Paving': 0.0,
#  'Ariel Corp': 0.0003944331482112448,
#  'Healthmark Ventures': 0.0,
#  'Squire Patton Boggs': 0.0015606337154218488,
#  'Sanderson Farms': 0.0,
#  'Allegiancy': 0.0,
#  'N00001489': 0.0035374371077702403,
#  'Hawkins Construction': 3.5223066510656627e-05,
#  'CEMEX SA de CV': 0.0007089458521546851,
#  'Hendrick Automotive': 0.0,
#  'University of Notre Dame': 0.0,
#  'Burns & McDonnell': 0.00012133233248980317,
#  'Field Fresh Foods': 0.0,
#  'South Texas Renal Care Group': 0.0,
#  'Consumer Technology Assn': 0.0001402909842695192,
#  'Wexford Capital': 0.00012630628991841595,
#  'University of Hawaii': 0.0,
#  'N00005582': 0.0028482011199710507,
#  'Center Point Inc': 0.0,
#  'Onyx Collection': 0.0,
#  'Navistar International': 0.0,
#  'Making America Prosperous': 0.0,
#  'Roche Holdings': 0.0,
#  'Bobby Cox Companies': 0.0,
#  'Globe University': 0.0,
#  'USAA': 0.0013036592825908498,
#  'American Academy of Dermatology Assn': 0.0008166861121922785,
#  'N00005285': 0.0037924782496858585,
#  'N00007833': 0.003258279872274898,
#  'Ischemix': 0.0,
#  'PCS Wireless': 0.0,
#  'Rex American': 0.0,
#  'Tenaska Energy': 3.2239780861982355e-05,
#  'National Rural Letter Carriers Assn': 5.9814851412929265e-06,
#  'AmeriPAC: The Fund for a Greater America': 0.001402836660233309,
#  'Pan Am Equities': 0.0,
#  'Princeton University': 0.0,
#  'Bates Amusements': 0.0,
#  'N00007232': 0.0027782908824525248,
#  'Oregon Health & Science University': 0.0,
#  'Peninsula Capital Advisors': 0.0,
#  'N00000078': 0.004333127133482004,
#  'N00034453': 0.005930948231980828,
#  'CoreCivic Inc': 0.0,
#  'Kitco Fiber Optics': 0.0,
#  'Resort Group': 0.0,
#  'Global Partners LP': 0.0,
#  'Bernstein Shur': 0.0,
#  'Strategic Growth Bank': 0.0,
#  'Big Time Products': 0.0,
#  'N00026163': 0.004422039110377396,
#  'N00001285': 0.0035898014907184447,
#  'Berkshire Partners': 0.0,
#  'TC Jacoby & Co': 0.0,
#  'Credit Union National Assn': 0.01385033099739752,
#  'N00033591': 0.003323786996629267,
#  'Marvin Windows': 0.0,
#  'ICI Homes': 0.0,
#  'N00027658': 0.004339030054960307,
#  'Maclean-Fogg Co': 0.0,
#  'N00031502': 0.001884014041211644,
#  'Barron Collier Companies': 0.0,
#  'American Resort Development Assn': 0.0030424239720302755,
#  'United Mine Workers of America': 0.0,
#  'Akonadi Foundation': 0.0009828526698649974,
#  'Balch & Bingham': 0.0,
#  'N00008274': 0.0038312004539716245,
#  'Rent-A-Center': 3.2246455309387357e-05,
#  'AG Hill Partners': 0.0,
#  'Amazon.com': 0.00025978750462171495,
#  'Kirkham Motorsports': 0.0,
#  'The Villages': 0.0,
#  'North Star Companies': 0.0,
#  'Kennedy Group': 0.0,
#  'Reed Smith LLP': 0.0,
#  'N00027441': 0.006453008820548976,
#  'N00012546': 0.005523453330905559,
#  'N00034746': 0.0047315356057272325,
#  'N00029736': 0.005678619361242746,
#  'Eaton Corp': 0.0,
#  'Mitchell Automotive Group': 0.0,
#  'Dorsey & Whitney': 4.5355866865454475e-05,
#  'Asplundh Tree Expert Co': 0.0,
#  'Ocean Riders Engineering': 0.0,
#  'Hunt Companies': 0.0011328305683361239,
#  'Cubic Energy': 0.0,
#  'M Resort LLC': 0.0,
#  'University of Colorado': 0.0,
#  'Eugene Lee Inc': 0.0,
#  'Apollo Education Group': 0.00010968086725230355,
#  'Daybrook Fisheries': 0.0,
#  'N00033630': 0.004106800498787393,
#  'Radiance Technologies': 0.0,
#  'Sandersville Railroad': 0.0,
#  'At&T Inc': 0.0,
#  'NRP Group': 0.0,
#  "O'Brien, Gentry & Scott": 0.0,
#  'Toshiba Corp': 0.0,
#  'Avant Inc': 0.0,
#  'Maschhoffs': 0.0,
#  'Campbell Soup': 0.0,
#  "Southern Glazer\\'s Wine & Spirits": 0.0,
#  'Alkermes plc': 0.0,
#  'N00029391': 0.004912463494213089,
#  'Ball Homes': 0.0,
#  'Robbins, Geller et al': 0.00025080665225784665,
#  'US Grid Co': 0.0,
#  'Hy Rock Excavation': 0.0,
#  'Kutak Rock LLP': 4.433515787673696e-05,
#  'N00007781': 0.0015998299528127821,
#  'Baskerville-Donovan Inc': 0.0,
#  'N00029574': 0.002560025830795369,
#  'American Assn/Oral & Maxillofacial Surg': 0.00011391470388235883,
#  'N00027623': 0.0041739632573148016,
#  'N00001003': 0.006215286816310789,
#  'Sandhills Publishing': 0.0,
#  'Dynetics Inc': 1.7211544607549303e-05,
#  'Washington University In St Louis': 0.0,
#  'Veterans United Home Loans': 0.0,
#  'Vorys, Sater et al': 0.0,
#  'USA Rice Federation': 0.0,
#  'Mintz, Levin et al': 0.0,
#  'Kmg Tool': 0.0,
#  'N00029404': 0.004452108307682216,
#  'Leggett & Platt': 0.0,
#  'Brilex Industries': 0.0,
#  'Bracey Supermarkets': 0.0,
#  'Lea County State Bank': 0.0,
#  'Charter Brokerage LLC': 7.223740255584896e-05,
#  'Comcast Corp': 0.044014589776691954,
#  'N00026148': 0.005193734705359233,
#  'N00007727': 0.004622356644307085,
#  'Norfolk Southern': 0.006780148078928366,
#  'Duane Morris Llp': 0.0,
#  'SpaceX': 2.505369762207262e-05,
#  'PVS Chemicals': 0.0,
#  'McVean Trading & Investments': 0.0,
#  'Fred Haas Toyota Country': 0.0,
#  'Sinclair Companies': 0.0006129683734918241,
#  'Conway Mackenzie': 0.0,
#  'CME Group': 0.000918575312592757,
#  'N00029147': 0.003694883258523301,
#  'Allstate Insurance': 0.0,
#  'Liberty Mutual': 0.0003922690813420009,
#  'N00034041': 0.004983723777771175,
#  'N00036928': 0.005923605176165932,
#  'Edison Electric Institute': 0.0,
#  'Texas Timberjack': 0.0,
#  'Rountree, Losee & Baldwin': 0.0,
#  'Abbott Laboratories': 0.001744132783369263,
#  'American University of Antigua': 0.0,
#  'VGM Group': 0.0001367774171344081,
#  'N00024809': 0.004780566196624931,
#  'N00035523': 0.004639631631615152,
#  'Apple Inc': 0.00015334054772017468,
#  'Fisher Barton Group': 0.0,
#  'Wellmont': 0.0,
#  'Terral River Service': 0.0,
#  'Yellowstone Bank': 6.729339307388798e-05,
#  'Southeastern Minerals': 0.0,
#  'Highfields Capital Management': 4.600966634463214e-05,
#  'N00028958': 0.004535246764936704,
#  'Meta Housing Corp': 0.0,
#  'McDermott, Will & Emery': 0.0,
#  'Haury & Smith Contractors': 0.0005336425121958485,
#  'American Academy of Pediatric Dentistry': 0.00010916720766325387,
#  'American Academy of Neurology': 2.607115801102162e-05,
#  'Western Oilfields Supply': 0.0,
#  'Quirk Auto': 0.0,
#  'Barrack, Rodos & Bacine': 0.0,
#  'Graham Companies': 0.0,
#  'N00034349': 0.0025110752870556264,
#  'Aetna Inc': 0.00028674610822459475,
#  'Willoughby & Hoefer': 0.0,
#  'Humana Inc': 0.00011928658840658804,
#  'N00033492': 0.004525677800600615,
#  'N00034120': 0.004245617784237866,
#  'Butler Amusements': 0.0,
#  'N00031934': 0.0028212547183606913,
#  'Digital Canal Corp': 0.0,
#  'N00000153': 0.0022712553479842215,
#  'Hackman Capital Partners': 0.0,
#  'Big Game Capital': 0.0,
#  'Leidos Inc': 0.0,
#  'Genesee & Wyoming': 0.0,
#  'N00026171': 0.0035094866764742343,
#  'Cgs Services': 0.0,
#  'Zivity LLC': 0.0,
#  'English Lloyd & Armenta': 0.0,
#  'Cops Monitoring': 0.0,
#  'Johnson City Medical Center': 0.0,
#  'United Technologies': 0.0003737952357885228,
#  'Seafarers International Union': 0.0,
#  'Park Circle Investments': 0.0,
#  'N00009585': 0.003928487270812336,
#  'Cheniere Energy': 7.71835894466555e-05,
#  'Drummond Co': 0.0006338111281798643,
#  'N00035616': 0.003708764044712379,
#  'Tulsa Bone & Joint': 0.0,
#  'Hfr Design': 0.0,
#  'N00033410': 0.005864953405453618,
#  'Intelligenesis': 0.0,
#  'Werner Enterprises': 1.9592102773236246e-05,
#  'University of Houston': 0.0,
#  'KKR & Co': 0.00024289004150010148,
#  'TRUST PAC': 0.0,
#  'Bonanza Oil': 0.0,
#  'G&C Autobody': 0.0,
#  'Nelson, Mullins et al': 7.558513308619091e-05,
#  'HK Research': 0.0,
#  'Kainos Capital': 0.0,
#  'National Pork Producers Council': 0.0,
#  'Crystal Run Healthcare': 0.0,
#  'N00033983': 0.004530436995468935,
#  'N00009659': 0.003058219619017028,
#  'North Carolina Leadership Fund': 0.0014124429027908684,
#  'Pilot Corp': 0.0,
#  'Energy Future Holdings Corp': 0.00022149588897655176,
#  'Heller Realty': 0.0,
#  'M&R Management': 0.0,
#  "Continuing America's Strength & Security": 0.0,
#  'Mosaic Media Group': 0.0,
#  'Leg Avenue Inc': 0.0,
#  'Time Warner': 0.0006327747944026133,
#  'N00009795': 0.0019801869727501193,
#  'Qualcomm Inc': 1.904986344838613e-05,
#  'Advocare International': 0.0,
#  'Michels Corp': 0.0,
#  'N00000781': 0.0046357009065733125,
#  'Telapex Inc': 7.25810009615234e-05,
#  'Dell Technologies': 0.0,
#  'Pop Fishing & Marine': 0.0,
#  'Mentor Network': 0.0,
#  'N00027239': 0.002919419139959806,
#  'Parkway Development': 0.0,
#  'Teramana Enterprises': 0.0,
#  'Hanning & Bean Enterprises': 0.0,
#  'Rockwell Collins Inc': 0.0,
#  'N00027860': 0.0031112467638059814,
#  'Bollinger Shipyards': 0.00013339955113961022,
#  'National Amusements Inc': 0.0010050746717220624,
#  'Mana Products': 0.0,
#  'Altos Eye Physicians': 0.0,
#  'N00002884': 0.0035615687392056643,
#  'Exxon Mobil': 0.0014226194404417906,
#  'N00034584': 0.0037149108480172793,
#  'Estrada Hinojosa & Co': 0.0,
#  'LCF Enterprises': 0.0,
#  'Lions Gate Entertainment': 0.0,
#  'Amscot Financial': 0.0,
#  'Carl Weinberg & Co': 0.0,
#  'Greater New York Hospital Assn': 0.0003222975157394479,
#  'Jayco Inc': 0.0,
#  'N00033508': 0.004017804267934036,
#  'Reclaim America PAC': 0.0,
#  'Jenner & Block': 0.0,
#  'Renaissance Technologies': 8.622743503793572e-05,
#  'N00036154': 0.0055892568391908174,
#  'N00032441': 0.004436700112314206,
#  'National Assn of Prof Insurance Agents': 2.5009911186913584e-05,
#  'Nextera Energy': 0.00010904292140641624,
#  'Oshkosh Corp': 0.0004477088278773335,
#  'Wayne Densch Inc': 0.0,
#  'N00030709': 0.002202148513182498,
#  'University of California': 0.004180210784920264,
#  'Timken Co': 0.0001436867766941343,
#  'N00002097': 0.0048653749911178905,
#  'Asuragen': 0.0,
#  'Agua Caliente Band of Cahuilla Indians': 0.0,
#  'CB Nanda & Assoc': 0.0,
#  'AES Corp': 0.00014975421372049176,
#  'Mackenzie Capital Management': 0.0003446683946667537,
#  'N00003522': 0.0024879972733986176,
#  'Directors Guild of America': 0.0,
#  'Ironworkers Union': 0.0019501217003235621,
#  'L Brands': 7.831252914955044e-05,
#  'Conference America': 0.0,
#  'Fedex Corp': 0.0,
#  'Digital Globe': 0.0,
#  'Allergan PLC': 0.00011765959614712257,
#  'Gilead Sciences': 0.0008835518509159956,
#  'Yancey Brothers': 8.980256177964744e-05,
#  'Maryland Assn for Concerned Citizens': 0.0,
#  'N00025482': 0.0034656691981841984,
#  'Hoosier Racing Tire': 0.0,
#  'N00024871': 0.0033225492029800136,
#  'Mack Energy': 0.0,
#  'Peirson & Patterson': 0.0,
#  'Otis Eastern': 0.00010154338648259223,
#  'Duke Energy': 0.0025641671443804074,
#  'N00033782': 0.005271433325837089,
#  'American Land Title Assn': 2.8169593677900647e-05,
#  'Signal Hill Petroleum': 0.0,
#  'Clos De La Tech': 0.008231762341099434,
#  'American Speech-Language-Hearing Assn': 3.2083050492980325e-05,
#  'Nightingale Home Healthcare': 0.0,
#  'John Roberts Toyota': 0.0,
#  'Emergency Medicine Physicians Inc': 0.0,
#  ...}

# %%
sorted_btw = sorted(btw_centrality, key=btw_centrality.get,reverse=True)
#btw_centrality includes ontributors and legislators, and we want only contributors: 
top_contribs = [node for node in sorted_btw if node in contrib_nodes]
print([node for node in top_contribs[:10]])
# Out:
# ['Blue Cross/Blue Shield', 'AT&T Inc', 'Boeing Co', 'American Crystal Sugar', 'National Assn of Realtors', 'American Bankers Assn', 'Berkshire Hathaway', 'Comcast Corp', 'Votesane PAC', 'JStreetPAC']

# %% [markdown]
# Blue Cross/Blue Shield has the highest degree, and is also the most central. Let's compare degrees and betweenness centrality.

# %%
plt.scatter([G.degree(node) for node in sorted(list(contrib_nodes))],
         [btw_centrality[node] for node in sorted(list(contrib_nodes))])
plt.xlabel('degree')
plt.ylabel('betweenness centrality');

# %% [markdown]
# Another perspective on betweenness is that high-betweenness nodes might be more likely to donate to legislators of both parties, since presumably there are fewer paths across party lines. (This suggests *assortativity*, which we will discuss in detail next week.)

# %%
# percent of recipients who are democrats
contrib = 'Blue Cross/Blue Shield'
[leg_attr(get_leg_by_cid(cid),'party') 
 for cid 
 in G.neighbors(contrib)].count('D')/nx.degree(G,contrib)
# Out:
# 0.32222222222222224

# %%
nx.degree(G,'Blue Cross/Blue Shield')
# Out:
# 90

# %%
[leg_attr(get_leg_by_cid(cid),'party') 
 for cid 
 in G.neighbors('Blue Cross/Blue Shield')].count('D')
# Out:
# 29

# %% [markdown]
# Now let's apply this code to all "big" contributors, with degree of 20 or more.

# %%
big_contribs = [node for node in contrib_nodes if nx.degree(G,node)>=20]

# %%
pct_dem = [[leg_attr(get_leg_by_cid(cid),'party') 
            for cid 
            in G.neighbors(contrib)].count('D')/nx.degree(G,contrib)
           for contrib
           in big_contribs]

# %%
plt.figure(figsize=[10,6])
plt.scatter(pct_dem,[btw_centrality[contrib] for contrib in big_contribs])
for i,contrib in enumerate(big_contribs):
    plt.text(pct_dem[i],btw_centrality[contrib],contrib)
plt.xlabel('Percent donations to Democrats')
plt.ylabel('Betweenness centrality');

# %% [markdown]
# **Your turn**: Redo the plot of degree versus betweenness centrality, using color and/or shape to differentiate:
#
# - Contributors who give at least 90% of their donations to Republicans
# - Contributors who give at least 90% of their donations to Democrats
# - All other contributors

# %%
#len(pct_dem)
#len(big_contribs)
#use zip to create a list comprehension
Dbig_contribs = [i for i,j in zip(big_contribs, pct_dem) if j >= .9]
Dpct_dem = [j for i,j in zip(big_contribs, pct_dem) if j >= .9]

# %%
#Or use zip to create a dict comprehension
dict_contrib = {i:j for i,j in zip(big_contribs, pct_dem) if j >= .9}
dict_contrib
# Out:
# {'American Assn for Justice': 0.9130434782608695,
#  'American Federation of Teachers': 1.0,
#  'American Fedn of St/Cnty/Munic Employees': 1.0,
#  'Border Health': 0.9629629629629629,
#  'Communications Workers of America': 0.9615384615384616,
#  'Intl Brotherhood of Electrical Workers': 1.0,
#  'JStreetPAC': 1.0,
#  'League of Conservation Voters': 1.0,
#  'Machinists/Aerospace Workers Union': 1.0,
#  'New Democrat Coalition': 1.0}

# %%
Rbig_contribs = [i for i,j in zip(big_contribs, pct_dem) if j <= .1]
Rpct_dem = [j for i,j in zip(big_contribs, pct_dem) if j <= .1]

# %%
plt.figure(figsize=[10,6])
plt.scatter(pct_dem,[btw_centrality[contrib] for contrib in big_contribs])
plt.scatter(Dpct_dem,[btw_centrality[contrib] for contrib in Dbig_contribs])
plt.scatter(Rpct_dem,[btw_centrality[contrib] for contrib in Rbig_contribs])
for i,contrib in enumerate(big_contribs):
    plt.text(pct_dem[i],btw_centrality[contrib],contrib) 
plt.xlabel('Percent donations to Democrats')
plt.ylabel('Betweenness centrality')
plt.legend(['Other','Democrat','Republican']);

# %% [markdown]
# ## Projection
#
# The legislator-contributor network is an example of an **affiliation network**.
#
# We can **project** across either set of nodes, inducing a network of legislators who share donors, or a network of contributors who donate to the same legislators. Let's now briefly investigate the projected legislator network.

# %%
# ?nx.projected_graph

# %%
# ?nx.degree

# %%
#projects the nodes onto the legislators
G_leg = nx.projected_graph(G,leg_nodes)

# %% [markdown]
# Let's plot the degree distribution of this graph

# %%
degrees = {leg:nx.degree(G_leg,leg) for leg in leg_nodes}

# %%
plt.loglog(sorted(degrees.values(),reverse=True));

# %% [markdown]
# Almost all nodes here have degree > 100, making the graph a little difficult to investigate. Let's look at the Georgia subgraph.

# %%
GA_legs = [leg for leg in leg_nodes if leg_attr(get_leg_by_cid(leg),'office')[:2]=='GA']
print(GA_legs)
# Out:
# ['N00033518', 'N00002593', 'N00002674', 'N00035516', 'N00032416', 'N00032243', 'N00026163', 'N00024871', 'N00032457', 'N00027848', 'N00002577', 'N00033720', 'N00026160', 'N00035346', 'N00030788', 'N00035347']

# %%
G_ga = G_leg.subgraph(GA_legs)

# %%
nx.draw_circular(G_ga)
# Out:
# /Users/shawnramirez/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/shawnramirez/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/shawnramirez/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/shawnramirez/anaconda/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")

# %% [markdown]
# The graph looks to be almost a clique.
#
# **Your turn** Compute the number of missing edges.

# %%
# your code here: Obtain the degrees for each legislator in GA_legs in the G_ga graph
degrees_GA = {leg:nx.degree(G_ga,leg) for leg in GA_legs}
max(degrees_GA.values())
# Out:
# 15

# %%
#total number of legislators connected with GA
len(GA_legs)
# Out:
# 16

# %%
degrees_GA
# Out:
# {'N00002577': 11,
#  'N00002593': 14,
#  'N00002674': 13,
#  'N00024871': 13,
#  'N00026160': 12,
#  'N00026163': 13,
#  'N00027848': 13,
#  'N00030788': 2,
#  'N00032243': 14,
#  'N00032416': 15,
#  'N00032457': 13,
#  'N00033518': 13,
#  'N00033720': 14,
#  'N00035346': 8,
#  'N00035347': 12,
#  'N00035516': 14}

# %%
#note that dictionaries are made up of a list of keys and a list of values
degrees_GA.keys()
# Out:
# dict_keys(['N00033518', 'N00002593', 'N00002674', 'N00035516', 'N00032416', 'N00032243', 'N00026163', 'N00024871', 'N00032457', 'N00027848', 'N00002577', 'N00033720', 'N00026160', 'N00035346', 'N00030788', 'N00035347'])

# %%
degrees_GA.values()
# Out:
# dict_values([13, 14, 13, 14, 15, 14, 13, 13, 13, 13, 11, 14, 12, 8, 2, 12])

# %%
#we can call both of those as a list of lists (items)
degrees_GA.items()
# Out:
# dict_items([('N00033518', 13), ('N00002593', 14), ('N00002674', 13), ('N00035516', 14), ('N00032416', 15), ('N00032243', 14), ('N00026163', 13), ('N00024871', 13), ('N00032457', 13), ('N00027848', 13), ('N00002577', 11), ('N00033720', 14), ('N00026160', 12), ('N00035346', 8), ('N00030788', 2), ('N00035347', 12)])

# %%
#if we call the items, then we can reference specific parts (the keys and values)
[str(value)+key for key,value in degrees_GA.items()]
# Out:
# ['13N00033518',
#  '14N00002593',
#  '13N00002674',
#  '14N00035516',
#  '15N00032416',
#  '14N00032243',
#  '13N00026163',
#  '13N00024871',
#  '13N00032457',
#  '13N00027848',
#  '11N00002577',
#  '14N00033720',
#  '12N00026160',
#  '8N00035346',
#  '2N00030788',
#  '12N00035347']

# %%
#this computes the total number of missing edges
sum(max(degrees_GA.values()) - value for value in degrees_GA.values())
# Out:
# 46

# %% [markdown]
# Here's another layout.

# %%
nx.draw_spring(G_ga)
#this did not come out right
# Out:
# /Users/shawnramirez/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:126: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   b = plt.ishold()
# /Users/shawnramirez/anaconda/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:138: MatplotlibDeprecationWarning: pyplot.hold is deprecated.
#     Future behavior will be consistent with the long-time default:
#     plot commands add elements without first clearing the
#     Axes and/or Figure.
#   plt.hold(b)
# /Users/shawnramirez/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py:917: UserWarning: axes.hold is deprecated. Please remove it from your matplotlibrc and/or style files.
#   warnings.warn(self.msg_depr_set % key)
# /Users/shawnramirez/anaconda/lib/python3.6/site-packages/matplotlib/rcsetup.py:152: UserWarning: axes.hold is deprecated, will be removed in 3.0
#   warnings.warn("axes.hold is deprecated, will be removed in 3.0")
